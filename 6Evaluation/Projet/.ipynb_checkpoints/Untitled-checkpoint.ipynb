# %% [markdown]
# # PROJET: Liste des matchs de l'équipe de France de 1904 à juin 2018

# %% [markdown]
# ## Aïmen Zemzi / Ryan Daoud

# %%
import numpy as np
import pandas as pd
import pymongo
import datetime

# %%
client = pymongo.MongoClient("mongodb://test:ryan1999@cluster0-shard-00-00.rcdsg.mongodb.net:27017,cluster0-shard-00-01.rcdsg.mongodb.net:27017,cluster0-shard-00-02.rcdsg.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-b2l3g1-shard-0&authSource=admin&w=majority")
database = client['exercices']
collection = database['projet']

# %%
df_foot = pd.read_csv("./data/df_matches.csv", encoding = "ISO-8859-1")
df_foot.head(2)
# Out:
#                  X2                 X4   X5            X6 adversaire  \
# 0      1er mai 1904  Belgique - France  3-3  Match amical   Belgique
# 1  12 fÃ©vrier 1905    France - Suisse  1-0  Match amical     Suisse
#
#    score_france  score_adversaire  penalty_france  penalty_adversaire  \
# 0             3                 3             NaN                 NaN
# 1             1                 0             NaN                 NaN
#
#          date    year outcome  no
# 0  1904-05-01  1904.0    draw   1
# 1  1905-02-12  1905.0     win   1

# %%
 print(df_foot.columns)
# Out:
# Index(['full_date', 'match', 'score', 'type', 'adversaire', 'score_france',
#        'score_adversaire', 'penalty_france', 'penalty_adversaire', 'date',
#        'year', 'outcome'],
#       dtype='object')

# %%
df_foot.rename(columns={'X2':'full_date'}, inplace=True)
df_foot.rename(columns={'X4':'match'}, inplace=True)
df_foot.rename(columns={'X5':'score'}, inplace=True)
df_foot.rename(columns={'X6':'type'}, inplace=True)
df_foot['date'] = pd.to_datetime(df_foot['date'], errors='coerce')
df_foot = df_foot.dropna(subset=['date'])
df_foot = df_foot.drop_duplicates(subset='date', keep='last')
l_d = df_foot.to_dict(orient='records')
for elt in l_d:
    for k,v in elt.items():
        if v == np.NaN:
            del elt[k]

# %%
collection.delete_many({})
collection.insert_many(l_d)

# %%
query = collection.find({"adversaire":"Belgique"})
list(query)
# Out:
# [{'_id': ObjectId('602e86232f5eeac022c7c978'),
#   'full_date': '1er mai 1904',
#   'match': 'Belgique - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1904-05-01',
#   'year': 1904.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c97a'),
#   'full_date': '7 mai 1905',
#   'match': 'Belgique - France',
#   'score': '7-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1905-05-07',
#   'year': 1905.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c97b'),
#   'full_date': '22 avril 1906',
#   'match': 'France - Belgique',
#   'score': '0-5',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1906-04-22',
#   'year': 1906.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c97d'),
#   'full_date': '21 avril 1907',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1907-04-21',
#   'year': 1907.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c980'),
#   'full_date': '12 avril 1908',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1908-04-12',
#   'year': 1908.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c983'),
#   'full_date': '8 mai 1909',
#   'match': 'Belgique - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1909-05-08',
#   'year': 1909.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c985'),
#   'full_date': '3 avril 1910',
#   'match': 'France - Belgique',
#   'score': '0-4',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1910-04-03',
#   'year': 1910.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c98c'),
#   'full_date': '30 avril 1911',
#   'match': 'Belgique - France',
#   'score': '7-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1911-04-30',
#   'year': 1911.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c98e'),
#   'full_date': '28 janvier 1912',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1912-01-28',
#   'year': 1912.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c992'),
#   'full_date': '16 fÃ©vrier 1913',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1913-02-16',
#   'year': 1913.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c996'),
#   'full_date': '25 janvier 1914',
#   'match': 'France - Belgique',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1914-01-25',
#   'year': 1914.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c99b'),
#   'full_date': '9 mars 1919',
#   'match': 'Belgique - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1919-03-09',
#   'year': 1919.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c99e'),
#   'full_date': '28 mars 1920',
#   'match': 'France - Belgique',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1920-03-28',
#   'year': 1920.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a4'),
#   'full_date': '6 mars 1921',
#   'match': 'Belgique - France',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1921-03-06',
#   'year': 1921.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a7'),
#   'full_date': '15 janvier 1922',
#   'match': 'France - Belgique',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1922-01-15',
#   'year': 1922.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9aa'),
#   'full_date': '25 fÃ©vrier 1923',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1923-02-25',
#   'year': 1923.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9af'),
#   'full_date': '13 janvier 1924',
#   'match': 'France - Belgique',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-01-13',
#   'year': 1924.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b5'),
#   'full_date': '11 novembre 1924',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-11-11',
#   'year': 1924.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b9'),
#   'full_date': '11 avril 1926',
#   'match': 'France - Belgique',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-04-11',
#   'year': 1926.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9be'),
#   'full_date': '20 juin 1926',
#   'match': 'Belgique - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-06-20',
#   'year': 1926.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c6'),
#   'full_date': '15 avril 1928',
#   'match': 'France - Belgique',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-04-15',
#   'year': 1928.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d0'),
#   'full_date': '26 mai 1929',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1929-05-26',
#   'year': 1929.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d3'),
#   'full_date': '13 avril 1930',
#   'match': 'France - Belgique',
#   'score': '1-6',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 6,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-04-13',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d6'),
#   'full_date': '25 mai 1930',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-05-25',
#   'year': 1930.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9da'),
#   'full_date': '7 dÃ©cembre 1930',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-12-07',
#   'year': 1930.0,
#   'outcome': 'draw',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e2'),
#   'full_date': '1er mai 1932',
#   'match': 'Belgique - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-05-01',
#   'year': 1932.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e9'),
#   'full_date': '26 mars 1933',
#   'match': 'France - Belgique',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-03-26',
#   'year': 1933.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ee'),
#   'full_date': '21 janvier 1934',
#   'match': 'Belgique - France',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-01-21',
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f8'),
#   'full_date': '14 avril 1935',
#   'match': 'Belgique - France',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-04-14',
#   'year': 1935.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9fe'),
#   'full_date': '8 mars 1936',
#   'match': 'France - Belgique',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1936-03-08',
#   'year': 1936.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca01'),
#   'full_date': '21 fÃ©vrier 1937',
#   'match': 'Belgique - France',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1937-02-21',
#   'year': 1937.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7ca07'),
#   'full_date': '30 janvier 1938',
#   'match': 'France - Belgique',
#   'score': '5-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 5,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1938-01-30',
#   'year': 1938.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7ca0a'),
#   'full_date': '5 juin 1938',
#   'match': 'France - Belgique',
#   'score': '3-1',
#   'type': 'Coupe du monde 1938 (HuitiÃ¨me de finale)',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1938-06-05',
#   'year': 1938.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca0f'),
#   'full_date': '18 mai 1939',
#   'match': 'Belgique - France',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1939-05-18',
#   'year': 1939.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca14'),
#   'full_date': '24 dÃ©cembre 1944',
#   'match': 'France - Belgique',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1944-12-24',
#   'year': 1944.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7ca18'),
#   'full_date': '15 dÃ©cembre 1945',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1945-12-15',
#   'year': 1945.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca20'),
#   'full_date': '1er juin 1947',
#   'match': 'France - Belgique',
#   'score': '4-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1947-06-01',
#   'year': 1947.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca25'),
#   'full_date': '6 juin 1948',
#   'match': 'Belgique - France',
#   'score': '4-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1948-06-06',
#   'year': 1948.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca27'),
#   'full_date': '17 octobre 1948',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1948-10-17',
#   'year': 1948.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca32'),
#   'full_date': '4 juin 1950',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1950-06-04',
#   'year': 1950.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7ca33'),
#   'full_date': '1er novembre 1950',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1950-11-01',
#   'year': 1950.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca3e'),
#   'full_date': '22 mai 1952',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1952-05-22',
#   'year': 1952.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca43'),
#   'full_date': '25 dÃ©cembre 1952',
#   'match': 'France - Belgique',
#   'score': '0-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1952-12-25',
#   'year': 1952.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7ca4d'),
#   'full_date': '30 mai 1954',
#   'match': 'Belgique - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1954-05-30',
#   'year': 1954.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7ca51'),
#   'full_date': '11 novembre 1954',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1954-11-11',
#   'year': 1954.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ca58'),
#   'full_date': '25 dÃ©cembre 1955',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1955-12-25',
#   'year': 1955.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ca5d'),
#   'full_date': '11 novembre 1956',
#   'match': 'France - Belgique',
#   'score': '6-3',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 6,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1956-11-11',
#   'year': 1956.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca62'),
#   'full_date': '27 octobre 1957',
#   'match': 'Belgique - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1957-10-27',
#   'year': 1957.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca72'),
#   'full_date': '1er mars 1959',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1959-03-01',
#   'year': 1959.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7ca77'),
#   'full_date': '28 fÃ©vrier 1960',
#   'match': 'Belgique - France',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1960-02-28',
#   'year': 1960.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7ca81'),
#   'full_date': '15 mars 1961',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1961-03-15',
#   'year': 1961.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7ca84'),
#   'full_date': '18 octobre 1961',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1961-10-18',
#   'year': 1961.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca94'),
#   'full_date': '25 dÃ©cembre 1963',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1963-12-25',
#   'year': 1963.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7ca99'),
#   'full_date': '2 dÃ©cembre 1964',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1964-12-02',
#   'year': 1964.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7caa1'),
#   'full_date': '20 avril 1966',
#   'match': 'France - Belgique',
#   'score': '0-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1966-04-20',
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7caa8'),
#   'full_date': '11 novembre 1966',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': "Qualifications pour l'Euro 1968",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1966-11-11',
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7caae'),
#   'full_date': '28 octobre 1967',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': "Qualifications pour l'Euro 1968",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1967-10-28',
#   'year': 1967.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cac0'),
#   'full_date': '15 novembre 1970',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1970-11-15',
#   'year': 1970.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cadb'),
#   'full_date': '12 octobre 1974',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': "Qualifications pour l'Euro 1976",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1974-10-12',
#   'year': 1974.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cae2'),
#   'full_date': '15 novembre 1975',
#   'match': 'France - Belgique',
#   'score': '0-0',
#   'type': "Qualifications pour l'Euro 1976",
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1975-11-15',
#   'year': 1975.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cb09'),
#   'full_date': '29 avril 1981',
#   'match': 'France - Belgique',
#   'score': '3-2',
#   'type': 'Qualifications pour la Coupe du monde 1982',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1981-04-29',
#   'year': 1981.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cb0b'),
#   'full_date': '9 septembre 1981',
#   'match': 'Belgique - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1982',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1981-09-09',
#   'year': 1981.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cb21'),
#   'full_date': '31 mai 1983',
#   'match': 'Belgique - France[29]',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1983-05-31',
#   'year': 1983.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cb2a'),
#   'full_date': '16 juin 1984',
#   'match': 'France - Belgique',
#   'score': '5-0',
#   'type': 'Euro 1984 (Groupe A)',
#   'adversaire': 'Belgique',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1984-06-16',
#   'year': 1984.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cb3f'),
#   'full_date': '28 juin 1986',
#   'match': 'France - Belgique',
#   'score': '4-2',
#   'type': 'Coupe du monde 1986 (Petite finale)',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1986-06-28',
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cb69'),
#   'full_date': '25 mars 1992',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1992-03-25',
#   'year': 1992.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cb8f'),
#   'full_date': '27 mars 1996',
#   'match': 'Belgique - France',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1996-03-27',
#   'year': 1996.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cba7'),
#   'full_date': '27 mai 1998',
#   'match': 'France - Belgique',
#   'score': '1-0',
#   'type': 'Tournoi Hassan II 1998 (amical)',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-05-27',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cbe1'),
#   'full_date': '18 mai 2002',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2002-05-18',
#   'year': 2002.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cbf9'),
#   'full_date': '18 fÃ©vrier 2004',
#   'match': 'Belgique - France',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2004-02-18',
#   'year': 2004.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7cc63'),
#   'full_date': '15 novembre 2011',
#   'match': 'France - Belgique',
#   'score': '0-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2011-11-15',
#   'year': 2011.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602e86232f5eeac022c7cc77'),
#   'full_date': '14 aoÃ»t 2013',
#   'match': 'Belgique - France',
#   'score': '0-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-08-14',
#   'year': 2013.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cc8f'),
#   'full_date': '7 juin 2015',
#   'match': 'France - Belgique',
#   'score': '3-4',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-06-07',
#   'year': 2015.0,
#   'outcome': 'loss',
#   'no': 3}]

# %%
query = collection.aggregate([{"$group" : {"_id" : "$adversaire", "average_goals_per_game" : {"$avg" : "$score_adversaire"}}}, {"$sort" : { "average_goals_per_game" : -1 }}])
list(query)
# Out:
# [{'_id': 'AzerbaÃ¯djan', 'average_goals_per_game': 5.0},
#  {'_id': 'Angleterre', 'average_goals_per_game': 2.707317073170732},
#  {'_id': 'Belgique', 'average_goals_per_game': 2.191780821917808},
#  {'_id': 'Italie', 'average_goals_per_game': 2.1578947368421053},
#  {'_id': 'Hongrie', 'average_goals_per_game': 2.1363636363636362},
#  {'_id': 'Pays-Bas', 'average_goals_per_game': 2.0384615384615383},
#  {'_id': 'Royaume des\nSerbes, Croates et SlovÃ¨nes',
#   'average_goals_per_game': 2.0},
#  {'_id': 'RFA', 'average_goals_per_game': 1.9333333333333333},
#  {'_id': 'Espagne', 'average_goals_per_game': 1.8},
#  {'_id': 'Autriche', 'average_goals_per_game': 1.7391304347826086},
#  {'_id': 'TchÃ©coslovaquie', 'average_goals_per_game': 1.7},
#  {'_id': 'BrÃ©sil', 'average_goals_per_game': 1.6},
#  {'_id': 'Colombie', 'average_goals_per_game': 1.6},
#  {'_id': 'Suisse', 'average_goals_per_game': 1.5789473684210527},
#  {'_id': 'Yougoslavie', 'average_goals_per_game': 1.55},
#  {'_id': 'URSS- France', 'average_goals_per_game': 1.5},
#  {'_id': 'Costa Rica', 'average_goals_per_game': 1.5},
#  {'_id': 'URSS', 'average_goals_per_game': 1.5},
#  {'_id': 'Russie', 'average_goals_per_game': 1.4285714285714286},
#  {'_id': 'Royaume de Yougoslavie',
#   'average_goals_per_game': 1.3333333333333333},
#  {'_id': 'RÃ©p. tchÃ¨que', 'average_goals_per_game': 1.25},
#  {'_id': 'Maroc', 'average_goals_per_game': 1.2},
#  {'_id': 'Bulgarie', 'average_goals_per_game': 1.1818181818181819},
#  {'_id': 'Portugal', 'average_goals_per_game': 1.16},
#  {'_id': 'Allemagne', 'average_goals_per_game': 1.1428571428571428},
#  {'_id': 'Argentine', 'average_goals_per_game': 1.0909090909090908},
#  {'_id': 'Chili', 'average_goals_per_game': 1.0},
#  {'_id': 'RDA', 'average_goals_per_game': 1.0},
#  {'_id': 'Pologne', 'average_goals_per_game': 1.0},
#  {'_id': 'BiÃ©lorussie', 'average_goals_per_game': 1.0},
#  {'_id': 'AlgÃ©rie', 'average_goals_per_game': 1.0},
#  {'_id': 'NorvÃ¨ge', 'average_goals_per_game': 1.0},
#  {'_id': 'SuÃ¨de', 'average_goals_per_game': 1.0},
#  {'_id': 'SÃ©lection FIFA', 'average_goals_per_game': 1.0},
#  {'_id': 'Cameroun', 'average_goals_per_game': 1.0},
#  {'_id': 'Roumanie', 'average_goals_per_game': 1.0},
#  {'_id': 'Iran', 'average_goals_per_game': 1.0},
#  {'_id': 'CorÃ©e du Sud', 'average_goals_per_game': 1.0},
#  {'_id': 'Australie- France', 'average_goals_per_game': 1.0},
#  {'_id': 'Uruguay', 'average_goals_per_game': 1.0},
#  {'_id': 'SÃ©nÃ©gal', 'average_goals_per_game': 1.0},
#  {'_id': 'Chine', 'average_goals_per_game': 1.0},
#  {'_id': 'Ã\x89cosse', 'average_goals_per_game': 0.9375},
#  {'_id': 'Irlande', 'average_goals_per_game': 0.8947368421052632},
#  {'_id': 'GrÃ¨ce', 'average_goals_per_game': 0.875},
#  {'_id': 'Mexique', 'average_goals_per_game': 0.8571428571428571},
#  {'_id': 'Japon', 'average_goals_per_game': 0.8333333333333334},
#  {'_id': 'Islande', 'average_goals_per_game': 0.8333333333333334},
#  {'_id': 'Pays de Galles', 'average_goals_per_game': 0.8},
#  {'_id': 'Danemark', 'average_goals_per_game': 0.8},
#  {'_id': 'Paraguay', 'average_goals_per_game': 0.8},
#  {'_id': 'Serbie', 'average_goals_per_game': 0.8},
#  {'_id': 'Tunisie', 'average_goals_per_game': 0.75},
#  {'_id': 'Bosnie-HerzÃ©govine', 'average_goals_per_game': 0.75},
#  {'_id': 'Afrique du Sud', 'average_goals_per_game': 0.75},
#  {'_id': 'Luxembourg', 'average_goals_per_game': 0.6666666666666666},
#  {'_id': 'IsraÃ«l', 'average_goals_per_game': 0.6666666666666666},
#  {'_id': 'SlovÃ©nie', 'average_goals_per_game': 0.6666666666666666},
#  {'_id': 'Croatie', 'average_goals_per_game': 0.6},
#  {'_id': 'Ukraine', 'average_goals_per_game': 0.5555555555555556},
#  {'_id': 'Nigeria', 'average_goals_per_game': 0.5},
#  {'_id': 'PÃ©rou', 'average_goals_per_game': 0.5},
#  {'_id': 'Turquie', 'average_goals_per_game': 0.5},
#  {'_id': 'Australie', 'average_goals_per_game': 0.5},
#  {'_id': 'Slovaquie', 'average_goals_per_game': 0.5},
#  {'_id': 'KoweÃ¯t', 'average_goals_per_game': 0.5},
#  {'_id': 'Irlande du Nord', 'average_goals_per_game': 0.5},
#  {'_id': 'Albanie', 'average_goals_per_game': 0.42857142857142855},
#  {'_id': 'ArmÃ©nie', 'average_goals_per_game': 0.4},
#  {'_id': 'Finlande', 'average_goals_per_game': 0.375},
#  {'_id': 'GÃ©orgie', 'average_goals_per_game': 0.25},
#  {'_id': 'Ã\x89tats-Unis', 'average_goals_per_game': 0.25},
#  {'_id': 'Chypre', 'average_goals_per_game': 0.25},
#  {'_id': 'Lettonie', 'average_goals_per_game': 0.0},
#  {'_id': 'Ã\x89gypte', 'average_goals_per_game': 0.0},
#  {'_id': 'Honduras', 'average_goals_per_game': 0.0},
#  {'_id': 'Ã\x8eles FÃ©roÃ©', 'average_goals_per_game': 0.0},
#  {'_id': 'Arabie saoudite', 'average_goals_per_game': 0.0},
#  {'_id': 'Estonie', 'average_goals_per_game': 0.0},
#  {'_id': "CÃ´te d'Ivoire", 'average_goals_per_game': 0.0},
#  {'_id': 'Ã\x89quateur', 'average_goals_per_game': 0.0},
#  {'_id': 'Afrique', 'average_goals_per_game': 0.0},
#  {'_id': 'France â\x80\x93 Italie', 'average_goals_per_game': 0.0},
#  {'_id': 'CONCACAF', 'average_goals_per_game': 0.0},
#  {'_id': 'Canada', 'average_goals_per_game': 0.0},
#  {'_id': 'Lituanie', 'average_goals_per_game': 0.0},
#  {'_id': 'JamaÃ¯que', 'average_goals_per_game': 0.0},
#  {'_id': 'Nouvelle-ZÃ©lande', 'average_goals_per_game': 0.0},
#  {'_id': 'Andorre', 'average_goals_per_game': 0.0},
#  {'_id': 'Malte', 'average_goals_per_game': 0.0},
#  {'_id': 'RF Yougoslavie', 'average_goals_per_game': 0.0},
#  {'_id': 'Togo', 'average_goals_per_game': 0.0}]

# %%
query = collection.aggregate([{"$group" : {"_id" : "$adversaire", "average_goals_per_game" : {"$avg" : "$score_france"}}}, {"$sort" : { "average_goals_per_game" : -1 }}])
list(query)
# Out:
# [{'_id': 'JamaÃ¯que', 'average_goals_per_game': 8.0},
#  {'_id': 'Lettonie', 'average_goals_per_game': 7.0},
#  {'_id': 'AzerbaÃ¯djan', 'average_goals_per_game': 6.0},
#  {'_id': 'SÃ©lection FIFA', 'average_goals_per_game': 5.0},
#  {'_id': 'CONCACAF', 'average_goals_per_game': 5.0},
#  {'_id': 'Ã\x89gypte', 'average_goals_per_game': 5.0},
#  {'_id': 'Nouvelle-ZÃ©lande', 'average_goals_per_game': 5.0},
#  {'_id': 'Malte', 'average_goals_per_game': 5.0},
#  {'_id': 'Arabie saoudite', 'average_goals_per_game': 4.0},
#  {'_id': 'Estonie', 'average_goals_per_game': 4.0},
#  {'_id': 'AlgÃ©rie', 'average_goals_per_game': 4.0},
#  {'_id': 'Luxembourg', 'average_goals_per_game': 3.9444444444444446},
#  {'_id': 'Ã\x8eles FÃ©roÃ©', 'average_goals_per_game': 3.6666666666666665},
#  {'_id': 'Chypre', 'average_goals_per_game': 3.375},
#  {'_id': 'SlovÃ©nie', 'average_goals_per_game': 3.3333333333333335},
#  {'_id': 'Turquie', 'average_goals_per_game': 3.0},
#  {'_id': 'Honduras', 'average_goals_per_game': 3.0},
#  {'_id': 'CorÃ©e du Sud', 'average_goals_per_game': 3.0},
#  {'_id': 'RF Yougoslavie', 'average_goals_per_game': 3.0},
#  {'_id': 'Islande', 'average_goals_per_game': 2.9166666666666665},
#  {'_id': 'GrÃ¨ce', 'average_goals_per_game': 2.875},
#  {'_id': 'ArmÃ©nie', 'average_goals_per_game': 2.8},
#  {'_id': 'Paraguay', 'average_goals_per_game': 2.8},
#  {'_id': 'Ã\x89tats-Unis', 'average_goals_per_game': 2.75},
#  {'_id': 'Australie', 'average_goals_per_game': 2.5},
#  {'_id': 'Royaume des\nSerbes, Croates et SlovÃ¨nes',
#   'average_goals_per_game': 2.5},
#  {'_id': 'Costa Rica', 'average_goals_per_game': 2.5},
#  {'_id': 'KoweÃ¯t', 'average_goals_per_game': 2.5},
#  {'_id': 'Maroc', 'average_goals_per_game': 2.4},
#  {'_id': 'Japon', 'average_goals_per_game': 2.3333333333333335},
#  {'_id': 'Andorre', 'average_goals_per_game': 2.3333333333333335},
#  {'_id': 'Finlande', 'average_goals_per_game': 2.25},
#  {'_id': 'Irlande du Nord', 'average_goals_per_game': 2.25},
#  {'_id': 'Pays de Galles', 'average_goals_per_game': 2.2},
#  {'_id': 'Chili', 'average_goals_per_game': 2.2},
#  {'_id': 'Mexique', 'average_goals_per_game': 2.142857142857143},
#  {'_id': 'Russie', 'average_goals_per_game': 2.142857142857143},
#  {'_id': 'Albanie', 'average_goals_per_game': 2.0},
#  {'_id': 'Afrique', 'average_goals_per_game': 2.0},
#  {'_id': 'Iran', 'average_goals_per_game': 2.0},
#  {'_id': 'Togo', 'average_goals_per_game': 2.0},
#  {'_id': 'Portugal', 'average_goals_per_game': 1.96},
#  {'_id': 'RFA', 'average_goals_per_game': 1.8666666666666667},
#  {'_id': 'Hongrie', 'average_goals_per_game': 1.8636363636363635},
#  {'_id': 'Croatie', 'average_goals_per_game': 1.8},
#  {'_id': 'Suisse', 'average_goals_per_game': 1.763157894736842},
#  {'_id': 'GÃ©orgie', 'average_goals_per_game': 1.75},
#  {'_id': 'Tunisie', 'average_goals_per_game': 1.75},
#  {'_id': 'Belgique', 'average_goals_per_game': 1.7397260273972603},
#  {'_id': 'Pays-Bas', 'average_goals_per_game': 1.7307692307692308},
#  {'_id': 'Bulgarie', 'average_goals_per_game': 1.7272727272727273},
#  {'_id': 'Autriche', 'average_goals_per_game': 1.6956521739130435},
#  {'_id': 'Pologne', 'average_goals_per_game': 1.6875},
#  {'_id': 'BiÃ©lorussie', 'average_goals_per_game': 1.6666666666666667},
#  {'_id': 'IsraÃ«l', 'average_goals_per_game': 1.6666666666666667},
#  {'_id': 'Cameroun', 'average_goals_per_game': 1.6666666666666667},
#  {'_id': 'Royaume de Yougoslavie',
#   'average_goals_per_game': 1.6666666666666667},
#  {'_id': 'Angleterre', 'average_goals_per_game': 1.6341463414634145},
#  {'_id': 'Colombie', 'average_goals_per_game': 1.6},
#  {'_id': 'Serbie', 'average_goals_per_game': 1.6},
#  {'_id': 'Ukraine', 'average_goals_per_game': 1.5555555555555556},
#  {'_id': "CÃ´te d'Ivoire", 'average_goals_per_game': 1.5},
#  {'_id': 'Slovaquie', 'average_goals_per_game': 1.5},
#  {'_id': 'Bosnie-HerzÃ©govine', 'average_goals_per_game': 1.5},
#  {'_id': 'Afrique du Sud', 'average_goals_per_game': 1.5},
#  {'_id': 'Chine', 'average_goals_per_game': 1.5},
#  {'_id': 'Italie', 'average_goals_per_game': 1.4736842105263157},
#  {'_id': 'NorvÃ¨ge', 'average_goals_per_game': 1.4666666666666666},
#  {'_id': 'TchÃ©coslovaquie', 'average_goals_per_game': 1.45},
#  {'_id': 'Ã\x89cosse', 'average_goals_per_game': 1.4375},
#  {'_id': 'Irlande', 'average_goals_per_game': 1.4210526315789473},
#  {'_id': 'Yougoslavie', 'average_goals_per_game': 1.4},
#  {'_id': 'SuÃ¨de', 'average_goals_per_game': 1.380952380952381},
#  {'_id': 'Allemagne', 'average_goals_per_game': 1.3571428571428572},
#  {'_id': 'Danemark', 'average_goals_per_game': 1.3333333333333333},
#  {'_id': 'Roumanie', 'average_goals_per_game': 1.3125},
#  {'_id': 'URSS', 'average_goals_per_game': 1.3},
#  {'_id': 'Lituanie', 'average_goals_per_game': 1.25},
#  {'_id': 'BrÃ©sil', 'average_goals_per_game': 1.2},
#  {'_id': 'RDA', 'average_goals_per_game': 1.1428571428571428},
#  {'_id': 'Espagne', 'average_goals_per_game': 1.0571428571428572},
#  {'_id': 'Nigeria', 'average_goals_per_game': 1.0},
#  {'_id': 'Ã\x89quateur', 'average_goals_per_game': 1.0},
#  {'_id': 'Canada', 'average_goals_per_game': 1.0},
#  {'_id': 'RÃ©p. tchÃ¨que', 'average_goals_per_game': 1.0},
#  {'_id': 'Argentine', 'average_goals_per_game': 0.6363636363636364},
#  {'_id': 'PÃ©rou', 'average_goals_per_game': 0.5},
#  {'_id': 'Uruguay', 'average_goals_per_game': 0.5},
#  {'_id': 'France â\x80\x93 Italie', 'average_goals_per_game': 0.0},
#  {'_id': 'URSS- France', 'average_goals_per_game': 0.0},
#  {'_id': 'Australie- France', 'average_goals_per_game': 0.0},
#  {'_id': 'SÃ©nÃ©gal', 'average_goals_per_game': 0.0}]

# %%
collection.create_index([("type", "text")])
query = collection.find({"$text": {'$search':'Coupe du monde'}}).sort([("year", -1)])
list(query)
# Out:
# [{'_id': ObjectId('602e86232f5eeac022c7ccba'),
#   'full_date': '26 juin 2018',
#   'match': 'Danemark - France',
#   'score': '0-0',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'Danemark',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-06-26',
#   'year': 2018.0,
#   'outcome': 'draw',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb9'),
#   'full_date': '21 juin 2018',
#   'match': 'France - PÃ©rou',
#   'score': '1-0',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'PÃ©rou',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-06-21',
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb8'),
#   'full_date': '16 juin 2018',
#   'match': 'France - Australie',
#   'score': '2-1',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'Australie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-06-16',
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb0'),
#   'full_date': '10 octobre 2017',
#   'match': 'France - BiÃ©lorussie',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-10-10',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7ccaf'),
#   'full_date': '7 octobre 2017',
#   'match': 'Bulgarie - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Bulgarie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-10-07',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7ccae'),
#   'full_date': '3 septembre 2017',
#   'match': 'France - Luxembourg',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Luxembourg',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-09-03',
#   'year': 2017.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ccad'),
#   'full_date': '31 aoÃ»t 2017',
#   'match': 'France - Pays-Bas',
#   'score': '4-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Pays-Bas',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-08-31',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ccab'),
#   'full_date': '9 juin 2017',
#   'match': 'SuÃ¨de - France',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-06-09',
#   'year': 2017.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cca8'),
#   'full_date': '25 mars 2017',
#   'match': 'Luxembourg - France',
#   'score': '1-3',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Luxembourg',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-03-25',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7cca6'),
#   'full_date': '11 novembre 2016',
#   'match': 'France - SuÃ¨de',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-11-11',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 16},
#  {'_id': ObjectId('602e86232f5eeac022c7cca5'),
#   'full_date': '10 octobre 2016',
#   'match': 'Pays-Bas - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Pays-Bas',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-10-10',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 15},
#  {'_id': ObjectId('602e86232f5eeac022c7cca4'),
#   'full_date': '7 octobre 2016',
#   'match': 'France - Bulgarie',
#   'score': '4-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Bulgarie',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-10-07',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 14},
#  {'_id': ObjectId('602e86232f5eeac022c7cca3'),
#   'full_date': '6 septembre 2016',
#   'match': 'BiÃ©lorussie - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-09-06',
#   'year': 2016.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602e86232f5eeac022c7cc84'),
#   'full_date': '25 juin 2014',
#   'match': 'Ã\x89quateur - France',
#   'score': '0-0',
#   'type': 'Coupe du monde 2014 (Groupe E)',
#   'adversaire': 'Ã\x89quateur',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2014-06-25',
#   'year': 2014.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cc83'),
#   'full_date': '20 juin 2014',
#   'match': 'Suisse - France',
#   'score': '2-5',
#   'type': 'Coupe du monde 2014 (Groupe E)',
#   'adversaire': 'Suisse',
#   'score_france': 5,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2014-06-20',
#   'year': 2014.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cc82'),
#   'full_date': '15 juin 2014',
#   'match': 'France - Honduras',
#   'score': '3-0',
#   'type': 'Coupe du monde 2014 (Groupe E)',
#   'adversaire': 'Honduras',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2014-06-15',
#   'year': 2014.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cc86'),
#   'full_date': '4 juillet 2014',
#   'match': 'France - Allemagne',
#   'score': '0-1',
#   'type': 'Coupe du monde 2014 (Quart de finale)',
#   'adversaire': 'Allemagne',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2014-07-04',
#   'year': 2014.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cc85'),
#   'full_date': '30 juin 2014',
#   'match': 'France - Nigeria',
#   'score': '2-0',
#   'type': 'Coupe du monde 2014 (HuitiÃ¨me de finale)',
#   'adversaire': 'Nigeria',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2014-06-30',
#   'year': 2014.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cc7b'),
#   'full_date': '15 octobre 2013',
#   'match': 'France - Finlande',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'Finlande',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-10-15',
#   'year': 2013.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cc79'),
#   'full_date': '10 septembre 2013',
#   'match': 'BiÃ©lorussie - France',
#   'score': '2-4',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-09-10',
#   'year': 2013.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cc78'),
#   'full_date': '6 septembre 2013',
#   'match': 'GÃ©orgie - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'GÃ©orgie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-09-06',
#   'year': 2013.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cc74'),
#   'full_date': '26 mars 2013',
#   'match': 'France - Espagne',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'Espagne',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-03-26',
#   'year': 2013.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cc73'),
#   'full_date': '22 mars 2013',
#   'match': 'France - GÃ©orgie',
#   'score': '3-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'GÃ©orgie',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-03-22',
#   'year': 2013.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cc7d'),
#   'full_date': '19 novembre 2013',
#   'match': 'France - Ukraine',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 2014 (Barrage retour)',
#   'adversaire': 'Ukraine',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-11-19',
#   'year': 2013.0,
#   'outcome': 'win',
#   'no': 12},
#  {'_id': ObjectId('602e86232f5eeac022c7cc7c'),
#   'full_date': '15 novembre 2013',
#   'match': 'Ukraine - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 2014 (Barrage aller)',
#   'adversaire': 'Ukraine',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2013-11-15',
#   'year': 2013.0,
#   'outcome': 'loss',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cc70'),
#   'full_date': '16 octobre 2012',
#   'match': 'Espagne - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'Espagne',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2012-10-16',
#   'year': 2012.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602e86232f5eeac022c7cc6e'),
#   'full_date': '11 septembre 2012',
#   'match': 'France - BiÃ©lorussie',
#   'score': '3-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2012-09-11',
#   'year': 2012.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cc6d'),
#   'full_date': '7 septembre 2012',
#   'match': 'Finlande - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'Finlande',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2012-09-07',
#   'year': 2012.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cc50'),
#   'full_date': '22 juin 2010',
#   'match': 'France - Afrique du Sud',
#   'score': '1-2',
#   'type': 'Coupe du monde 2010 (Groupe A)',
#   'adversaire': 'Afrique du Sud',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2010-06-22',
#   'year': 2010.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cc4f'),
#   'full_date': '17 juin 2010',
#   'match': 'France - Mexique',
#   'score': '0-2',
#   'type': 'Coupe du monde 2010 (Groupe A)',
#   'adversaire': 'Mexique',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2010-06-17',
#   'year': 2010.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cc4e'),
#   'full_date': '11 juin 2010',
#   'match': 'Uruguay - France',
#   'score': '0-0',
#   'type': 'Coupe du monde 2010 (Groupe A)',
#   'adversaire': 'Uruguay',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2010-06-11',
#   'year': 2010.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cc47'),
#   'full_date': '14 octobre 2009',
#   'match': 'France - Autriche',
#   'score': '3-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Autriche',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-10-14',
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cc46'),
#   'full_date': '10 octobre 2009',
#   'match': 'France - Ã\x8eles FÃ©roÃ©',
#   'score': '5-0',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Ã\x8eles FÃ©roÃ©',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-10-10',
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cc45'),
#   'full_date': '9 septembre 2009',
#   'match': 'Serbie - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Serbie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-09-09',
#   'year': 2009.0,
#   'outcome': 'draw',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cc44'),
#   'full_date': '5 septembre 2009',
#   'match': 'France - Roumanie',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Roumanie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-09-05',
#   'year': 2009.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cc43'),
#   'full_date': '12 aoÃ»t 2009',
#   'match': 'Ã\x8eles FÃ©roÃ© - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Ã\x8eles FÃ©roÃ©',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-08-12',
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cc40'),
#   'full_date': '1er avril 2009',
#   'match': 'France - Lituanie',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Lituanie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-04-01',
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cc3f'),
#   'full_date': '28 mars 2009',
#   'match': 'Lituanie - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Lituanie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-03-28',
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cc49'),
#   'full_date': '18 novembre 2009',
#   'match': 'France - Irlande',
#   'score': '1-1 ap',
#   'type': 'Qualifications pour la Coupe du monde 2010 (Barrage retour)',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-11-18',
#   'year': 2009.0,
#   'outcome': 'draw',
#   'no': 12},
#  {'_id': ObjectId('602e86232f5eeac022c7cc48'),
#   'full_date': '14 novembre 2009',
#   'match': 'Irlande - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2010 (Barrage aller)',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2009-11-14',
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cc3b'),
#   'full_date': '11 octobre 2008',
#   'match': 'Roumanie - France',
#   'score': '2-2',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Roumanie',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2008-10-11',
#   'year': 2008.0,
#   'outcome': 'draw',
#   'no': 12},
#  {'_id': ObjectId('602e86232f5eeac022c7cc3a'),
#   'full_date': '10 septembre 2008',
#   'match': 'France - Serbie',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Serbie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2008-09-10',
#   'year': 2008.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cc39'),
#   'full_date': '6 septembre 2008',
#   'match': 'Autriche - France',
#   'score': '3-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Autriche',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2008-09-06',
#   'year': 2008.0,
#   'outcome': 'loss',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cc1d'),
#   'full_date': '9 juillet 2006',
#   'match': 'Italie - France',
#   'score': '1-1 ap(5-3) tab',
#   'type': 'Coupe du monde 2006 (Finale)',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': 3.0,
#   'penalty_adversaire': 5.0,
#   'date': '2006-07-09',
#   'year': 2006.0,
#   'outcome': 'draw',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cc1c'),
#   'full_date': '5 juillet 2006',
#   'match': 'Portugal - France',
#   'score': '0-1',
#   'type': 'Coupe du monde 2006 (Demi-finale)',
#   'adversaire': 'Portugal',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2006-07-05',
#   'year': 2006.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cc19'),
#   'full_date': '23 juin 2006',
#   'match': 'Togo - France',
#   'score': '0-2',
#   'type': 'Coupe du monde 2006 (Groupe G)',
#   'adversaire': 'Togo',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2006-06-23',
#   'year': 2006.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cc18'),
#   'full_date': '18 juin 2006',
#   'match': 'France - CorÃ©e du Sud',
#   'score': '1-1',
#   'type': 'Coupe du monde 2006 (Groupe G)',
#   'adversaire': 'CorÃ©e du Sud',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2006-06-18',
#   'year': 2006.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cc17'),
#   'full_date': '13 juin 2006',
#   'match': 'France - Suisse',
#   'score': '0-0',
#   'type': 'Coupe du monde 2006 (Groupe G)',
#   'adversaire': 'Suisse',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2006-06-13',
#   'year': 2006.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cc1b'),
#   'full_date': '1er juillet 2006',
#   'match': 'France - BrÃ©sil',
#   'score': '1-0',
#   'type': 'Coupe du monde 2006 (Quart de finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2006-07-01',
#   'year': 2006.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cc1a'),
#   'full_date': '27 juin 2006',
#   'match': 'Espagne - France',
#   'score': '1-3',
#   'type': 'Coupe du monde 2006 (HuitiÃ¨me de finale)',
#   'adversaire': 'Espagne',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2006-06-27',
#   'year': 2006.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cc10'),
#   'full_date': '12 octobre 2005',
#   'match': 'France - Chypre',
#   'score': '4-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Chypre',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2005-10-12',
#   'year': 2005.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cc0f'),
#   'full_date': '8 octobre 2005',
#   'match': 'Suisse - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Suisse',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2005-10-08',
#   'year': 2005.0,
#   'outcome': 'draw',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cc0e'),
#   'full_date': '7 septembre 2005',
#   'match': 'Irlande - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2005-09-07',
#   'year': 2005.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cc0d'),
#   'full_date': '3 septembre 2005',
#   'match': 'France - Ã\x8eles FÃ©roÃ©',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Ã\x8eles FÃ©roÃ©',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2005-09-03',
#   'year': 2005.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cc0a'),
#   'full_date': '29 mars 2005',
#   'match': 'IsraÃ«l - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'IsraÃ«l',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2005-03-29',
#   'year': 2005.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cc09'),
#   'full_date': '26 mars 2005',
#   'match': 'France - Suisse',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Suisse',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2005-03-26',
#   'year': 2005.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cc06'),
#   'full_date': '13 octobre 2004',
#   'match': 'Chypre - France',
#   'score': '0-2',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Chypre',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2004-10-13',
#   'year': 2004.0,
#   'outcome': 'win',
#   'no': 14},
#  {'_id': ObjectId('602e86232f5eeac022c7cc05'),
#   'full_date': '9 octobre 2004',
#   'match': 'France - Irlande',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Irlande',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2004-10-09',
#   'year': 2004.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602e86232f5eeac022c7cc04'),
#   'full_date': '8 septembre 2004',
#   'match': 'Ã\x8eles FÃ©roÃ© - France',
#   'score': '0-2',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Ã\x8eles FÃ©roÃ©',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2004-09-08',
#   'year': 2004.0,
#   'outcome': 'win',
#   'no': 12},
#  {'_id': ObjectId('602e86232f5eeac022c7cc03'),
#   'full_date': '4 septembre 2004',
#   'match': 'France - IsraÃ«l',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'IsraÃ«l',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2004-09-04',
#   'year': 2004.0,
#   'outcome': 'draw',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cbf3'),
#   'full_date': '29 juin 2003',
#   'match': 'France - Cameroun',
#   'score': '1-0 apb.e.o.',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Finale)',
#   'adversaire': 'Cameroun',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2003-06-29',
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cbf1'),
#   'full_date': '22 juin 2003',
#   'match': 'France - Nouvelle-ZÃ©lande',
#   'score': '5-0',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Groupe A)',
#   'adversaire': 'Nouvelle-ZÃ©lande',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2003-06-22',
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cbf0'),
#   'full_date': '20 juin 2003',
#   'match': 'France - Japon',
#   'score': '2-1',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Groupe A)',
#   'adversaire': 'Japon',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2003-06-20',
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cbef'),
#   'full_date': '18 juin 2003',
#   'match': 'France - Colombie',
#   'score': '1-0',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Groupe A)',
#   'adversaire': 'Colombie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2003-06-18',
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cbf2'),
#   'full_date': '26 juin 2003',
#   'match': 'France - Turquie',
#   'score': '3-2',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Demi-finale)',
#   'adversaire': 'Turquie',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2003-06-26',
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cbe5'),
#   'full_date': '11 juin 2002',
#   'match': 'Danemark - France',
#   'score': '2-0',
#   'type': 'Coupe du monde 2002 (Groupe A)',
#   'adversaire': 'Danemark',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2002-06-11',
#   'year': 2002.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cbe4'),
#   'full_date': '6 juin 2002',
#   'match': 'France - Uruguay',
#   'score': '0-0',
#   'type': 'Coupe du monde 2002 (Groupe A)',
#   'adversaire': 'Uruguay',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2002-06-06',
#   'year': 2002.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cbe3'),
#   'full_date': '31 mai 2002',
#   'match': 'France - SÃ©nÃ©gal',
#   'score': '0-1',
#   'type': 'Coupe du monde 2002 (Groupe A)',
#   'adversaire': 'SÃ©nÃ©gal',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2002-05-31',
#   'year': 2002.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cbd9'),
#   'full_date': '10 juin 2001',
#   'match': 'Japon - France',
#   'score': '0-1',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Finale)',
#   'adversaire': 'Japon',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2001-06-10',
#   'year': 2001.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cbd7'),
#   'full_date': '3 juin 2001',
#   'match': 'France - Mexique',
#   'score': '4-0',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Groupe A)',
#   'adversaire': 'Mexique',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2001-06-03',
#   'year': 2001.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cbd6'),
#   'full_date': '1er juin 2001',
#   'match': 'Australie- France',
#   'score': '1-0',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Groupe A)',
#   'adversaire': 'Australie- France',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2001-06-01',
#   'year': 2001.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cbd8'),
#   'full_date': '7 juin 2001',
#   'match': 'France - BrÃ©sil',
#   'score': '2-1',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Demi-finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2001-06-07',
#   'year': 2001.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cbd5'),
#   'full_date': '30 mai 2001',
#   'match': 'CorÃ©e du Sud - France',
#   'score': '0-5',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Groupe A)[36]',
#   'adversaire': 'CorÃ©e du Sud',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2001-05-30',
#   'year': 2001.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cbcf'),
#   'full_date': '7 octobre 2000',
#   'match': 'Afrique du Sud - France',
#   'score': '0-0[1]',
#   'type': 'Coupe du challenge 2000[2] (amical)',
#   'adversaire': 'Afrique du Sud',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2000-10-07',
#   'year': 2000.0,
#   'outcome': 'draw',
#   'no': 16},
#  {'_id': ObjectId('602e86232f5eeac022c7cbb0'),
#   'full_date': '12 juillet 1998',
#   'match': 'BrÃ©sil - France',
#   'score': '0-3',
#   'type': 'Coupe du monde 1998 (Finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-07-12',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 14},
#  {'_id': ObjectId('602e86232f5eeac022c7cbaf'),
#   'full_date': '8 juillet 1998',
#   'match': 'France - Croatie',
#   'score': '2-1',
#   'type': 'Coupe du monde 1998 (Demi-finale)',
#   'adversaire': 'Croatie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-07-08',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 13},
#  {'_id': ObjectId('602e86232f5eeac022c7cbac'),
#   'full_date': '24 juin 1998',
#   'match': 'France - Danemark',
#   'score': '2-1',
#   'type': 'Coupe du monde 1998 (Groupe C)',
#   'adversaire': 'Danemark',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-06-24',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cbab'),
#   'full_date': '18 juin 1998',
#   'match': 'France - Arabie saoudite',
#   'score': '4-0',
#   'type': 'Coupe du monde 1998 (Groupe C)',
#   'adversaire': 'Arabie saoudite',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-06-18',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cbaa'),
#   'full_date': '12 juin 1998',
#   'match': 'France - Afrique du Sud',
#   'score': '3-0',
#   'type': 'Coupe du monde 1998 (Groupe C)',
#   'adversaire': 'Afrique du Sud',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-06-12',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cbae'),
#   'full_date': '3 juillet 1998',
#   'match': 'France â\x80\x93 Italie',
#   'score': '0-0 ap(4-3) tab',
#   'type': 'Coupe du monde 1998 (Quart de finale)',
#   'adversaire': 'France â\x80\x93 Italie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 3.0,
#   'date': '1998-07-03',
#   'year': 1998.0,
#   'outcome': 'draw',
#   'no': 12},
#  {'_id': ObjectId('602e86232f5eeac022c7cbad'),
#   'full_date': '28 juin 1998',
#   'match': 'France - Paraguay',
#   'score': '1-0 apb.e.o.',
#   'type': 'Coupe du monde 1998 (HuitiÃ¨me de finale)',
#   'adversaire': 'Paraguay',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-06-28',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cba3'),
#   'full_date': '28 janvier 1998',
#   'match': 'France - Espagne',
#   'score': '1-0',
#   'type': 'Match amical (Inauguration du Stade de France)',
#   'adversaire': 'Espagne',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1998-01-28',
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7cb7f'),
#   'full_date': '29 mai 1994',
#   'match': 'Japon - France',
#   'score': '1-4',
#   'type': 'Coupe Kirin 1994 (Amical)',
#   'adversaire': 'Japon',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1994-05-29',
#   'year': 1994.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cb7e'),
#   'full_date': '26 mai 1994',
#   'match': 'France - Australie',
#   'score': '1-0',
#   'type': 'Coupe Kirin 1994 (Amical)',
#   'adversaire': 'Australie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1994-05-26',
#   'year': 1994.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cb7b'),
#   'full_date': '17 novembre 1993',
#   'match': 'France - Bulgarie',
#   'score': '1-2',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Bulgarie',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1993-11-17',
#   'year': 1993.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cb7a'),
#   'full_date': '13 octobre 1993',
#   'match': 'France - IsraÃ«l',
#   'score': '2-3',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'IsraÃ«l',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1993-10-13',
#   'year': 1993.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cb79'),
#   'full_date': '8 septembre 1993',
#   'match': 'Finlande - France',
#   'score': '0-2',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Finlande',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1993-09-08',
#   'year': 1993.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cb78'),
#   'full_date': '22 aoÃ»t 1993',
#   'match': 'SuÃ¨de - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1993-08-22',
#   'year': 1993.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cb75'),
#   'full_date': '28 avril 1993',
#   'match': 'France - SuÃ¨de',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1993-04-28',
#   'year': 1993.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cb74'),
#   'full_date': '27 mars 1993',
#   'match': 'Autriche - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Autriche',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1993-03-27',
#   'year': 1993.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cb73'),
#   'full_date': '17 fÃ©vrier 1993',
#   'match': 'IsraÃ«l - France',
#   'score': '0-4',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'IsraÃ«l',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1993-02-17',
#   'year': 1993.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7cb76'),
#   'full_date': '16 juin 1993',
#   'match': 'France - Colombie',
#   'score': '1-3',
#   'type': 'Match amical (Inauguration du Stade de Dillon)',
#   'adversaire': 'Colombie',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1993-06-16',
#   'year': 1993.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cb72'),
#   'full_date': '14 novembre 1992',
#   'match': 'France - Finlande',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Finlande',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1992-11-14',
#   'year': 1992.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cb71'),
#   'full_date': '14 octobre 1992',
#   'match': 'France - Autriche',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Autriche',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1992-10-14',
#   'year': 1992.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cb70'),
#   'full_date': '9 septembre 1992',
#   'match': 'Bulgarie - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Bulgarie',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1992-09-09',
#   'year': 1992.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cb5b'),
#   'full_date': '24 janvier 1990',
#   'match': 'France - RDA',
#   'score': '3-0',
#   'type': 'Tournoi du KoweÃ¯t 1990 (amical)',
#   'adversaire': 'RDA',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1990-01-24',
#   'year': 1990.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cb5a'),
#   'full_date': '21 janvier 1990',
#   'match': 'KoweÃ¯t - France',
#   'score': '0-1',
#   'type': 'Tournoi du KoweÃ¯t 1990 (amical)',
#   'adversaire': 'KoweÃ¯t',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1990-01-21',
#   'year': 1990.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7cb59'),
#   'full_date': '18 novembre 1989',
#   'match': 'France - Chypre',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Chypre',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1989-11-18',
#   'year': 1989.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cb58'),
#   'full_date': '11 octobre 1989',
#   'match': 'France - Ã\x89cosse',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1989-10-11',
#   'year': 1989.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cb57'),
#   'full_date': '5 septembre 1989',
#   'match': 'NorvÃ¨ge - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1989-09-05',
#   'year': 1989.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cb55'),
#   'full_date': '29 avril 1989',
#   'match': 'France - Yougoslavie',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Yougoslavie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1989-04-29',
#   'year': 1989.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cb54'),
#   'full_date': '8 mars 1989',
#   'match': 'Ã\x89cosse - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1989-03-08',
#   'year': 1989.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cb52'),
#   'full_date': '19 novembre 1988',
#   'match': 'Yougoslavie - France',
#   'score': '3-2',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Yougoslavie',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1988-11-19',
#   'year': 1988.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cb51'),
#   'full_date': '22 octobre 1988',
#   'match': 'Chypre - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Chypre',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1988-10-22',
#   'year': 1988.0,
#   'outcome': 'draw',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cb50'),
#   'full_date': '28 septembre 1988',
#   'match': 'France - NorvÃ¨ge',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1988-09-28',
#   'year': 1988.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cb3f'),
#   'full_date': '28 juin 1986',
#   'match': 'France - Belgique',
#   'score': '4-2',
#   'type': 'Coupe du monde 1986 (Petite finale)',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1986-06-28',
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cb3e'),
#   'full_date': '25 juin 1986',
#   'match': 'France - RFA',
#   'score': '0-2',
#   'type': 'Coupe du monde 1986 (Demi-finale)',
#   'adversaire': 'RFA',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1986-06-25',
#   'year': 1986.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cb3b'),
#   'full_date': '9 juin 1986',
#   'match': 'France - Hongrie',
#   'score': '3-0',
#   'type': 'Coupe du monde 1986 (Groupe C)',
#   'adversaire': 'Hongrie',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1986-06-09',
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cb3a'),
#   'full_date': '5 juin 1986',
#   'match': 'France - URSS',
#   'score': '1-1',
#   'type': 'Coupe du monde 1986 (Groupe C)',
#   'adversaire': 'URSS',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1986-06-05',
#   'year': 1986.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cb39'),
#   'full_date': '1er juin 1986',
#   'match': 'France - Canada',
#   'score': '1-0',
#   'type': 'Coupe du monde 1986 (Groupe C)',
#   'adversaire': 'Canada',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1986-06-01',
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cb3d'),
#   'full_date': '21 juin 1986',
#   'match': 'BrÃ©sil - France',
#   'score': '1-1 ap(3-4) tab',
#   'type': 'Coupe du monde 1986 (Quart de finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 3.0,
#   'date': '1986-06-21',
#   'year': 1986.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cb3c'),
#   'full_date': '17 juin 1986',
#   'match': 'France - Italie',
#   'score': '2-0',
#   'type': 'Coupe du monde 1986 (HuitiÃ¨me de finale)',
#   'adversaire': 'Italie',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1986-06-17',
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cb33'),
#   'full_date': '21 aoÃ»t 1985',
#   'match': 'France - Uruguay',
#   'score': '2-0',
#   'type': 'Coupe intercontinentale 1985',
#   'adversaire': 'Uruguay',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1985-08-21',
#   'year': 1985.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cb36'),
#   'full_date': '16 novembre 1985',
#   'match': 'France - Yougoslavie',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Yougoslavie',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1985-11-16',
#   'year': 1985.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cb35'),
#   'full_date': '30 octobre 1985',
#   'match': 'France - Luxembourg',
#   'score': '6-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Luxembourg',
#   'score_france': 6,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1985-10-30',
#   'year': 1985.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cb34'),
#   'full_date': '11 septembre 1985',
#   'match': 'RDA - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'RDA',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1985-09-11',
#   'year': 1985.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cb32'),
#   'full_date': '2 mai 1985',
#   'match': 'Bulgarie - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Bulgarie',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1985-05-02',
#   'year': 1985.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cb31'),
#   'full_date': '3 avril 1985',
#   'match': 'Yougoslavie - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Yougoslavie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1985-04-03',
#   'year': 1985.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7cb30'),
#   'full_date': '8 dÃ©cembre 1984',
#   'match': 'France - RDA',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'RDA',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1984-12-08',
#   'year': 1984.0,
#   'outcome': 'win',
#   'no': 12},
#  {'_id': ObjectId('602e86232f5eeac022c7cb2f'),
#   'full_date': '21 novembre 1984',
#   'match': 'France - Bulgarie',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Bulgarie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1984-11-21',
#   'year': 1984.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cb2e'),
#   'full_date': '13 octobre 1984',
#   'match': 'Luxembourg - France',
#   'score': '0-4',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Luxembourg',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1984-10-13',
#   'year': 1984.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cb1a'),
#   'full_date': '10 juillet 1982',
#   'match': 'Pologne - France',
#   'score': '3-2',
#   'type': 'Coupe du monde 1982 (Petite finale)',
#   'adversaire': 'Pologne',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1982-07-10',
#   'year': 1982.0,
#   'outcome': 'loss',
#   'no': 12},
#  {'_id': ObjectId('602e86232f5eeac022c7cb19'),
#   'full_date': '8 juillet 1982',
#   'match': 'RFA - France [6]',
#   'score': '3-3 ap(5-4) tab',
#   'type': 'Coupe du monde 1982 (Demi-finale)',
#   'adversaire': 'RFA',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 5.0,
#   'date': '1982-07-08',
#   'year': 1982.0,
#   'outcome': 'draw',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cb16'),
#   'full_date': '24 juin 1982',
#   'match': 'France - TchÃ©coslovaquie',
#   'score': '1-1',
#   'type': 'Coupe du monde 1982 (Groupe 4)',
#   'adversaire': 'TchÃ©coslovaquie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1982-06-24',
#   'year': 1982.0,
#   'outcome': 'draw',
#   'no': 8},
# ...
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1969-09-10',
#   'year': 1969.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cab4'),
#   'full_date': '6 novembre 1968',
#   'match': 'France - NorvÃ¨ge',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 1970',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1968-11-06',
#   'year': 1968.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7caa5'),
#   'full_date': '20 juillet 1966',
#   'match': 'Angleterre - France',
#   'score': '2-0',
#   'type': 'Coupe du monde 1966 (Groupe A)',
#   'adversaire': 'Angleterre',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1966-07-20',
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7caa4'),
#   'full_date': '15 juillet 1966',
#   'match': 'Uruguay - France',
#   'score': '2-1',
#   'type': 'Coupe du monde 1966 (Groupe A)',
#   'adversaire': 'Uruguay',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1966-07-15',
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7caa3'),
#   'full_date': '13 juillet 1966',
#   'match': 'France - Mexique',
#   'score': '1-1',
#   'type': 'Coupe du monde 1966 (Groupe A)',
#   'adversaire': 'Mexique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1966-07-13',
#   'year': 1966.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca9f'),
#   'full_date': '6 novembre 1965',
#   'match': 'France - Luxembourg',
#   'score': '4-1',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'Luxembourg',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1965-11-06',
#   'year': 1965.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ca9e'),
#   'full_date': '9 octobre 1965',
#   'match': 'France - Yougoslavie',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'Yougoslavie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1965-10-09',
#   'year': 1965.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca9d'),
#   'full_date': '15 septembre 1965',
#   'match': 'NorvÃ¨ge - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1965-09-15',
#   'year': 1965.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca9b'),
#   'full_date': '18 avril 1965',
#   'match': 'Yougoslavie - France',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'Yougoslavie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1965-04-18',
#   'year': 1965.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7ca98'),
#   'full_date': '11 novembre 1964',
#   'match': 'France - NorvÃ¨ge',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1964-11-11',
#   'year': 1964.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca97'),
#   'full_date': '4 octobre 1964',
#   'match': 'Luxembourg - France',
#   'score': '0-2',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'Luxembourg',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1964-10-04',
#   'year': 1964.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca85'),
#   'full_date': '12 novembre 1961',
#   'match': 'Bulgarie - France',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1962',
#   'adversaire': 'Bulgarie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1961-11-12',
#   'year': 1961.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca83'),
#   'full_date': '28 septembre 1961',
#   'match': 'France - Finlande',
#   'score': '5-1',
#   'type': 'Qualifications pour la Coupe du monde 1962',
#   'adversaire': 'Finlande',
#   'score_france': 5,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1961-09-28',
#   'year': 1961.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca87'),
#   'full_date': '16 dÃ©cembre 1961',
#   'match': 'Bulgarie - France',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1962 (Barrage)',
#   'adversaire': 'Bulgarie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1961-12-16',
#   'year': 1961.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ca80'),
#   'full_date': '11 dÃ©cembre 1960',
#   'match': 'France - Bulgarie',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 1962',
#   'adversaire': 'Bulgarie',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1960-12-11',
#   'year': 1960.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7ca7c'),
#   'full_date': '25 septembre 1960',
#   'match': 'Finlande - France',
#   'score': '1-2',
#   'type': 'Qualifications pour la Coupe du monde 1962',
#   'adversaire': 'Finlande',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1960-09-25',
#   'year': 1960.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ca6c'),
#   'full_date': '28 juin 1958',
#   'match': 'France - RFA',
#   'score': '6-3',
#   'type': 'Coupe du monde 1958 (Petite finale)',
#   'adversaire': 'RFA',
#   'score_france': 6,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1958-06-28',
#   'year': 1958.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7ca6b'),
#   'full_date': '24 juin 1958',
#   'match': 'BrÃ©sil - France',
#   'score': '5-2',
#   'type': 'Coupe du monde 1958 (Demi-finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1958-06-24',
#   'year': 1958.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ca69'),
#   'full_date': '15 juin 1958',
#   'match': 'France - Ã\x89cosse',
#   'score': '2-1',
#   'type': 'Coupe du monde 1958 (Groupe B)',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1958-06-15',
#   'year': 1958.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca68'),
#   'full_date': '11 juin 1958',
#   'match': 'Yougoslavie - France',
#   'score': '3-2',
#   'type': 'Coupe du monde 1958 (Groupe B)',
#   'adversaire': 'Yougoslavie',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1958-06-11',
#   'year': 1958.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca67'),
#   'full_date': '8 juin 1958',
#   'match': 'France - Paraguay',
#   'score': '7-3',
#   'type': 'Coupe du monde 1958 (Groupe B)',
#   'adversaire': 'Paraguay',
#   'score_france': 7,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1958-06-08',
#   'year': 1958.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca6a'),
#   'full_date': '19 juin 1958',
#   'match': 'France - Irlande du Nord',
#   'score': '4-0',
#   'type': 'Coupe du monde 1958 (Quart de finale)',
#   'adversaire': 'Irlande du Nord',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1958-06-19',
#   'year': 1958.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ca62'),
#   'full_date': '27 octobre 1957',
#   'match': 'Belgique - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1957-10-27',
#   'year': 1957.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca60'),
#   'full_date': '1er septembre 1957',
#   'match': 'Islande - France',
#   'score': '1-5',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Islande',
#   'score_france': 5,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1957-09-01',
#   'year': 1957.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca5f'),
#   'full_date': '2 juin 1957',
#   'match': 'France - Islande',
#   'score': '8-0',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Islande',
#   'score_france': 8,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1957-06-02',
#   'year': 1957.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7ca5d'),
#   'full_date': '11 novembre 1956',
#   'match': 'France - Belgique',
#   'score': '6-3',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 6,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1956-11-11',
#   'year': 1956.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca4f'),
#   'full_date': '19 juin 1954',
#   'match': 'France - Mexique',
#   'score': '3-2',
#   'type': 'Coupe du monde 1954 (Groupe A)',
#   'adversaire': 'Mexique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1954-06-19',
#   'year': 1954.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca4e'),
#   'full_date': '16 juin 1954',
#   'match': 'Yougoslavie - France',
#   'score': '1-0',
#   'type': 'Coupe du monde 1954 (Groupe A)',
#   'adversaire': 'Yougoslavie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1954-06-16',
#   'year': 1954.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca4b'),
#   'full_date': '17 dÃ©cembre 1953',
#   'match': 'France - Luxembourg',
#   'score': '8-0',
#   'type': 'Qualifications pour la Coupe du monde 1954',
#   'adversaire': 'Luxembourg',
#   'score_france': 8,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1953-12-17',
#   'year': 1953.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7ca4a'),
#   'full_date': '25 novembre 1953',
#   'match': 'France - Irlande',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1954',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1953-11-25',
#   'year': 1953.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ca47'),
#   'full_date': '4 octobre 1953',
#   'match': 'Irlande - France',
#   'score': '3-5',
#   'type': 'Qualifications pour la Coupe du monde 1954',
#   'adversaire': 'Irlande',
#   'score_france': 5,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1953-10-04',
#   'year': 1953.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ca46'),
#   'full_date': '20 septembre 1953',
#   'match': 'Luxembourg - France',
#   'score': '1-6',
#   'type': 'Qualifications pour la Coupe du monde 1954',
#   'adversaire': 'Luxembourg',
#   'score_france': 6,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1953-09-20',
#   'year': 1953.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ca2e'),
#   'full_date': '30 octobre 1949',
#   'match': 'France - Yougoslavie',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1950',
#   'adversaire': 'Yougoslavie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1949-10-30',
#   'year': 1949.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ca2d'),
#   'full_date': '9 octobre 1949',
#   'match': 'Yougoslavie - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1950',
#   'adversaire': 'Yougoslavie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1949-10-09',
#   'year': 1949.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ca30'),
#   'full_date': '11 dÃ©cembre 1949',
#   'match': 'Yougoslavie - France',
#   'score': '3-2',
#   'type': 'Qualifications pour la\nCoupe du monde 1950 (Barrage)',
#   'adversaire': 'Yougoslavie',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1949-12-11',
#   'year': 1949.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7ca0b'),
#   'full_date': '12 juin 1938',
#   'match': 'France - Italie',
#   'score': '1-3',
#   'type': 'Coupe du monde 1938 (Quart de finale)',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1938-06-12',
#   'year': 1938.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ca0a'),
#   'full_date': '5 juin 1938',
#   'match': 'France - Belgique',
#   'score': '3-1',
#   'type': 'Coupe du monde 1938 (HuitiÃ¨me de finale)',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1938-06-05',
#   'year': 1938.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f3'),
#   'full_date': '27 mai 1934',
#   'match': 'Autriche - France',
#   'score': '3-2',
#   'type': 'Coupe du monde 1934 (HuitiÃ¨me de finale)',
#   'adversaire': 'Autriche',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-05-27',
#   'year': 1934.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f1'),
#   'full_date': '15 avril 1934',
#   'match': 'Luxembourg - France',
#   'score': '1-6',
#   'type': 'Qualifications pour la Coupe du monde 1934',
#   'adversaire': 'Luxembourg',
#   'score_france': 6,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-04-15',
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d9'),
#   'full_date': '19 juillet 1930',
#   'match': 'Chili - France',
#   'score': '1-0',
#   'type': 'Coupe du monde 1930 (Groupe 1)',
#   'adversaire': 'Chili',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-07-19',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d8'),
#   'full_date': '15 juillet 1930',
#   'match': 'Argentine - France',
#   'score': '1-0',
#   'type': 'Coupe du monde 1930 (Groupe 1)',
#   'adversaire': 'Argentine',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-07-15',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d7'),
#   'full_date': '13 juillet 1930',
#   'match': 'France - Mexique',
#   'score': '4-1',
#   'type': 'Coupe du monde 1930 (Groupe 1)[73]',
#   'adversaire': 'Mexique',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-07-13',
#   'year': 1930.0,
#   'outcome': 'win',
#   'no': 7}]

# %%
query = collection.find({"outcome":"win"})
query.count()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# 408

# %%
query_two = collection.find({"outcome":"draw"})
query_two.count()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# 177

# %%
query_three = collection.find({"outcome":"loss"})
query_three.count()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# 250

# %%
query = collection.find({"penalty_france": {"$ne" : 'nan'}})
list(query)
# Out:
# [{'_id': ObjectId('602e86232f5eeac022c7c978'),
#   'full_date': '1er mai 1904',
#   'match': 'Belgique - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1904-05-01',
#   'year': 1904.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c979'),
#   'full_date': '12 fÃ©vrier 1905',
#   'match': 'France - Suisse',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1905-02-12',
#   'year': 1905.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c97a'),
#   'full_date': '7 mai 1905',
#   'match': 'Belgique - France',
#   'score': '7-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1905-05-07',
#   'year': 1905.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c97b'),
#   'full_date': '22 avril 1906',
#   'match': 'France - Belgique',
#   'score': '0-5',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1906-04-22',
#   'year': 1906.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c97c'),
#   'full_date': '1er novembre 1906',
#   'match': 'France - Angleterre',
#   'score': '0-15',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1906-11-01',
#   'year': 1906.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c97d'),
#   'full_date': '21 avril 1907',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1907-04-21',
#   'year': 1907.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c97e'),
#   'full_date': '8 mars 1908',
#   'match': 'Suisse - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1908-03-08',
#   'year': 1908.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c97f'),
#   'full_date': '23 mars 1908',
#   'match': 'Angleterre - France',
#   'score': '12-0',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 10,
#   'score_adversaire': 12,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1908-03-23',
#   'year': 1908.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c980'),
#   'full_date': '12 avril 1908',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1908-04-12',
#   'year': 1908.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c981'),
#   'full_date': '10 mai 1908',
#   'match': 'Pays-Bas - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Pays-Bas',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1908-05-10',
#   'year': 1908.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c982'),
#   'full_date': '22 octobre 1908',
#   'match': 'France - Danemark',
#   'score': '1-17',
#   'type': 'Jeux olympiques 1908[40](Demi-finale)',
#   'adversaire': 'Danemark',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1908-10-22',
#   'year': 1908.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c983'),
#   'full_date': '8 mai 1909',
#   'match': 'Belgique - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1909-05-08',
#   'year': 1909.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c984'),
#   'full_date': '22 mai 1909',
#   'match': 'France - Angleterre',
#   'score': '0-11',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1909-05-22',
#   'year': 1909.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c985'),
#   'full_date': '3 avril 1910',
#   'match': 'France - Belgique',
#   'score': '0-4',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1910-04-03',
#   'year': 1910.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c986'),
#   'full_date': '16 avril 1910',
#   'match': 'Angleterre - France',
#   'score': '10-1',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 11,
#   'score_adversaire': 10,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1910-04-16',
#   'year': 1910.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c987'),
#   'full_date': '15 mai 1910',
#   'match': 'Italie - France',
#   'score': '6-2',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 2,
#   'score_adversaire': 6,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1910-05-15',
#   'year': 1910.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c988'),
#   'full_date': '1er janvier 1911',
#   'match': 'France - Hongrie',
#   'score': '0-3',
#   'type': 'Match amical',
#   'adversaire': 'Hongrie',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1911-01-01',
#   'year': 1911.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c989'),
#   'full_date': '23 mars 1911',
#   'match': 'France - Angleterre',
#   'score': '0-3',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1911-03-23',
#   'year': 1911.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c98a'),
#   'full_date': '9 avril 1911',
#   'match': 'France - Italie',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1911-04-09',
#   'year': 1911.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c98b'),
#   'full_date': '23 avril 1911',
#   'match': 'Suisse - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1911-04-23',
#   'year': 1911.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c98c'),
#   'full_date': '30 avril 1911',
#   'match': 'Belgique - France',
#   'score': '7-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1911-04-30',
#   'year': 1911.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c98d'),
#   'full_date': '29 octobre 1911',
#   'match': 'Luxembourg - France',
#   'score': '1-4',
#   'type': 'Match amical',
#   'adversaire': 'Luxembourg',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1911-10-29',
#   'year': 1911.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c98e'),
#   'full_date': '28 janvier 1912',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1912-01-28',
#   'year': 1912.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c98f'),
#   'full_date': '18 fÃ©vrier 1912',
#   'match': 'France - Suisse',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1912-02-18',
#   'year': 1912.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c990'),
#   'full_date': '17 mars 1912',
#   'match': 'Italie - France',
#   'score': '3-4',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1912-03-17',
#   'year': 1912.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c991'),
#   'full_date': '12 janvier 1913',
#   'match': 'France - Italie',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1913-01-12',
#   'year': 1913.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c992'),
#   'full_date': '16 fÃ©vrier 1913',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1913-02-16',
#   'year': 1913.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c993'),
#   'full_date': '27 fÃ©vrier 1913',
#   'match': 'France - Angleterre',
#   'score': '1-4',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1913-02-27',
#   'year': 1913.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c994'),
#   'full_date': '9 mars 1913',
#   'match': 'Suisse - France',
#   'score': '1-4',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1913-03-09',
#   'year': 1913.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c995'),
#   'full_date': '20 avril 1913',
#   'match': 'France - Luxembourg',
#   'score': '8-0',
#   'type': 'Match amical',
#   'adversaire': 'Luxembourg',
#   'score_france': 8,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1913-04-20',
#   'year': 1913.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c996'),
#   'full_date': '25 janvier 1914',
#   'match': 'France - Belgique',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1914-01-25',
#   'year': 1914.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c997'),
#   'full_date': '8 fÃ©vrier 1914',
#   'match': 'Luxembourg - France',
#   'score': '5-4',
#   'type': 'Match amical',
#   'adversaire': 'Luxembourg',
#   'score_france': 4,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1914-02-08',
#   'year': 1914.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c998'),
#   'full_date': '8 mars 1914',
#   'match': 'France - Suisse',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1914-03-08',
#   'year': 1914.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c999'),
#   'full_date': '29 mars 1914',
#   'match': 'Italie - France',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1914-03-29',
#   'year': 1914.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c99a'),
#   'full_date': '31 mai 1914',
#   'match': 'Hongrie - France',
#   'score': '5-1',
#   'type': 'Match amical',
#   'adversaire': 'Hongrie',
#   'score_france': 1,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1914-05-31',
#   'year': 1914.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c99b'),
#   'full_date': '9 mars 1919',
#   'match': 'Belgique - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1919-03-09',
#   'year': 1919.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c99c'),
#   'full_date': '18 janvier 1920',
#   'match': 'Italie - France',
#   'score': '9-4',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 4,
#   'score_adversaire': 9,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1920-01-18',
#   'year': 1920.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c99d'),
#   'full_date': '29 fÃ©vrier 1920',
#   'match': 'Suisse - France',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1920-02-29',
#   'year': 1920.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c99e'),
#   'full_date': '28 mars 1920',
#   'match': 'France - Belgique',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1920-03-28',
#   'year': 1920.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c99f'),
#   'full_date': '5 avril 1920',
#   'match': 'France - Angleterre',
#   'score': '0-5',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 0,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1920-04-05',
#   'year': 1920.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a0'),
#   'full_date': '29 aoÃ»t 1920',
#   'match': 'France - Italie',
#   'score': '3-1',
#   'type': 'Jeux olympiques 1920 (Quart de finale)',
#   'adversaire': 'Italie',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1920-08-29',
#   'year': 1920.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a1'),
#   'full_date': '31 aoÃ»t 1920',
#   'match': 'TchÃ©coslovaquie - France',
#   'score': '4-1',
#   'type': 'Jeux olympiques 1920 (Demi-finale)',
#   'adversaire': 'TchÃ©coslovaquie',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1920-08-31',
#   'year': 1920.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a2'),
#   'full_date': '8 fÃ©vrier 1921',
#   'match': 'France - Irlande',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1921-02-08',
#   'year': 1921.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a3'),
#   'full_date': '20 fÃ©vrier 1921',
#   'match': 'France - Italie',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1921-02-20',
#   'year': 1921.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a4'),
#   'full_date': '6 mars 1921',
#   'match': 'Belgique - France',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1921-03-06',
#   'year': 1921.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a5'),
#   'full_date': '5 mai 1921',
#   'match': 'France - Angleterre',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1921-05-05',
#   'year': 1921.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a6'),
#   'full_date': '13 novembre 1921',
#   'match': 'France - Pays-Bas',
#   'score': '0-5',
#   'type': 'Match amical',
#   'adversaire': 'Pays-Bas',
#   'score_france': 0,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1921-11-13',
#   'year': 1921.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a7'),
#   'full_date': '15 janvier 1922',
#   'match': 'France - Belgique',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1922-01-15',
#   'year': 1922.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a8'),
#   'full_date': '30 avril 1922',
#   'match': 'France - Espagne',
#   'score': '0-4',
#   'type': 'Match amical',
#   'adversaire': 'Espagne',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1922-04-30',
#   'year': 1922.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9a9'),
#   'full_date': '28 janvier 1923',
#   'match': 'Espagne - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Espagne',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1923-01-28',
#   'year': 1923.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9aa'),
#   'full_date': '25 fÃ©vrier 1923',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1923-02-25',
#   'year': 1923.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ab'),
#   'full_date': '2 avril 1923',
#   'match': 'Pays-Bas - France',
#   'score': '8-1',
#   'type': 'Match amical',
#   'adversaire': 'Pays-Bas',
#   'score_france': 1,
#   'score_adversaire': 8,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1923-04-02',
#   'year': 1923.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ac'),
#   'full_date': '22 avril 1923',
#   'match': 'France - Suisse',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1923-04-22',
#   'year': 1923.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ad'),
#   'full_date': '10 mai 1923',
#   'match': 'France - Angleterre',
#   'score': '1-4',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1923-05-10',
#   'year': 1923.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ae'),
#   'full_date': '28 octobre 1923',
#   'match': 'France - NorvÃ¨ge',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1923-10-28',
#   'year': 1923.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9af'),
#   'full_date': '13 janvier 1924',
#   'match': 'France - Belgique',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-01-13',
#   'year': 1924.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b0'),
#   'full_date': '23 mars 1924',
#   'match': 'Suisse - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-03-23',
#   'year': 1924.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b1'),
#   'full_date': '17 mai 1924',
#   'match': 'France - Angleterre',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-05-17',
#   'year': 1924.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b2'),
#   'full_date': '27 mai 1924',
#   'match': 'France - Lettonie',
#   'score': '7-0',
#   'type': 'Jeux olympiques 1924 (HuitiÃ¨me de finale)',
#   'adversaire': 'Lettonie',
#   'score_france': 7,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-05-27',
#   'year': 1924.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b3'),
#   'full_date': '1er juin 1924',
#   'match': 'France - Uruguay',
#   'score': '1-5',
#   'type': 'Jeux olympiques 1924 (Quart de finale)',
#   'adversaire': 'Uruguay',
#   'score_france': 1,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-06-01',
#   'year': 1924.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b4'),
#   'full_date': '4 juin 1924',
#   'match': 'France - Hongrie',
#   'score': '0-1',
#   'type': 'Match amical',
#   'adversaire': 'Hongrie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-06-04',
#   'year': 1924.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b5'),
#   'full_date': '11 novembre 1924',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1924-11-11',
#   'year': 1924.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b6'),
#   'full_date': '22 mars 1925',
#   'match': 'Italie - France',
#   'score': '7-0',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 0,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1925-03-22',
#   'year': 1925.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b7'),
#   'full_date': '19 avril 1925',
#   'match': 'France - Autriche',
#   'score': '0-4',
#   'type': 'Match amical',
#   'adversaire': 'Autriche',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1925-04-19',
#   'year': 1925.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b8'),
#   'full_date': '25 mai 1925',
#   'match': 'France - Angleterre',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1925-05-25',
#   'year': 1925.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9b9'),
#   'full_date': '11 avril 1926',
#   'match': 'France - Belgique',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-04-11',
#   'year': 1926.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ba'),
#   'full_date': '18 avril 1926',
#   'match': 'France - Portugal',
#   'score': '4-2',
#   'type': 'Match amical',
#   'adversaire': 'Portugal',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-04-18',
#   'year': 1926.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9bb'),
#   'full_date': '25 avril 1926',
#   'match': 'France - Suisse',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-04-25',
#   'year': 1926.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9bc'),
#   'full_date': '30 mai 1926',
#   'match': 'Autriche - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Autriche',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-05-30',
#   'year': 1926.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9bd'),
#   'full_date': '14 juin 1926',
#   'match': 'France - Royaume des\nSerbes, Croates et SlovÃ¨nes',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Royaume des\nSerbes, Croates et SlovÃ¨nes',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-06-14',
#   'year': 1926.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9be'),
#   'full_date': '20 juin 1926',
#   'match': 'Belgique - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1926-06-20',
#   'year': 1926.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9bf'),
#   'full_date': '16 mars 1927',
#   'match': 'Portugal - France',
#   'score': '4-0',
#   'type': 'Match amical',
#   'adversaire': 'Portugal',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1927-03-16',
#   'year': 1927.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c0'),
#   'full_date': '24 avril 1927',
#   'match': 'France - Italie',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1927-04-24',
#   'year': 1927.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c1'),
#   'full_date': '22 mai 1927',
#   'match': 'France - Espagne',
#   'score': '1-4',
#   'type': 'Match amical',
#   'adversaire': 'Espagne',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1927-05-22',
#   'year': 1927.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c2'),
#   'full_date': '26 mai 1927',
#   'match': 'France - Angleterre',
#   'score': '0-6',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 0,
#   'score_adversaire': 6,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1927-05-26',
#   'year': 1927.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c3'),
#   'full_date': '12 juin 1927',
#   'match': 'Hongrie - France',
#   'score': '13-1',
#   'type': 'Match amical',
#   'adversaire': 'Hongrie',
#   'score_france': 11,
#   'score_adversaire': 13,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1927-06-12',
#   'year': 1927.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c4'),
#   'full_date': '21 fÃ©vrier 1928',
#   'match': 'France - Irlande',
#   'score': '4-0',
#   'type': 'Match amical',
#   'adversaire': 'Irlande',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-02-21',
#   'year': 1928.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c5'),
#   'full_date': '11 mars 1928',
#   'match': 'Suisse - France',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 3,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-03-11',
#   'year': 1928.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c6'),
#   'full_date': '15 avril 1928',
#   'match': 'France - Belgique',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-04-15',
#   'year': 1928.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c7'),
#   'full_date': '29 avril 1928',
#   'match': 'France - Portugal',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Portugal',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-04-29',
#   'year': 1928.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c8'),
#   'full_date': '13 mai 1928',
#   'match': 'France - TchÃ©coslovaquie',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'TchÃ©coslovaquie',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-05-13',
#   'year': 1928.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9c9'),
#   'full_date': '17 mai 1928',
#   'match': 'France - Angleterre',
#   'score': '1-5',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 1,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-05-17',
#   'year': 1928.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ca'),
#   'full_date': '29 mai 1928',
#   'match': 'France - Italie',
#   'score': '3-4',
#   'type': 'Jeux olympiques 1928 (Premier tour)',
#   'adversaire': 'Italie',
#   'score_france': 3,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1928-05-29',
#   'year': 1928.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7c9cb'),
#   'full_date': '24 fÃ©vrier 1929',
#   'match': 'France - Hongrie',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Hongrie',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1929-02-24',
#   'year': 1929.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9cc'),
#   'full_date': '24 mars 1929',
#   'match': 'France - Portugal',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Portugal',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1929-03-24',
#   'year': 1929.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9cd'),
#   'full_date': '14 avril 1929',
#   'match': 'Espagne - France',
#   'score': '8-1',
#   'type': 'Match amical',
#   'adversaire': 'Espagne',
#   'score_france': 1,
#   'score_adversaire': 8,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1929-04-14',
#   'year': 1929.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ce'),
#   'full_date': '9 mai 1929',
#   'match': 'France - Angleterre',
#   'score': '1-4',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1929-05-09',
#   'year': 1929.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9cf'),
#   'full_date': '19 mai 1929',
#   'match': 'France - Royaume des\nSerbes, Croates et SlovÃ¨nes',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Royaume des\nSerbes, Croates et SlovÃ¨nes',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1929-05-19',
#   'year': 1929.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d0'),
#   'full_date': '26 mai 1929',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1929-05-26',
#   'year': 1929.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d1'),
#   'full_date': '23 fÃ©vrier 1930',
#   'match': 'Portugal - France',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Portugal',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-02-23',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d2'),
#   'full_date': '23 mars 1930',
#   'match': 'France - Suisse',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-03-23',
#   'year': 1930.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d3'),
#   'full_date': '13 avril 1930',
#   'match': 'France - Belgique',
#   'score': '1-6',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 6,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-04-13',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d4'),
#   'full_date': '11 mai 1930',
#   'match': 'France - TchÃ©coslovaquie',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'TchÃ©coslovaquie',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-05-11',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d5'),
#   'full_date': '18 mai 1930',
#   'match': 'France - Ã\x89cosse',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-05-18',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d6'),
#   'full_date': '25 mai 1930',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-05-25',
#   'year': 1930.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d7'),
#   'full_date': '13 juillet 1930',
#   'match': 'France - Mexique',
#   'score': '4-1',
#   'type': 'Coupe du monde 1930 (Groupe 1)[73]',
#   'adversaire': 'Mexique',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-07-13',
#   'year': 1930.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d8'),
#   'full_date': '15 juillet 1930',
#   'match': 'Argentine - France',
#   'score': '1-0',
#   'type': 'Coupe du monde 1930 (Groupe 1)',
#   'adversaire': 'Argentine',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-07-15',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7c9d9'),
#   'full_date': '19 juillet 1930',
#   'match': 'Chili - France',
#   'score': '1-0',
#   'type': 'Coupe du monde 1930 (Groupe 1)',
#   'adversaire': 'Chili',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-07-19',
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7c9da'),
#   'full_date': '7 dÃ©cembre 1930',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1930-12-07',
#   'year': 1930.0,
#   'outcome': 'draw',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7c9db'),
#   'full_date': '25 janvier 1931',
#   'match': 'Italie - France',
#   'score': '5-0',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 0,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1931-01-25',
#   'year': 1931.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9dc'),
#   'full_date': '15 fÃ©vrier 1931',
#   'match': 'France - TchÃ©coslovaquie',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'TchÃ©coslovaquie',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1931-02-15',
#   'year': 1931.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9dd'),
#   'full_date': '15 mars 1931',
#   'match': 'France - Allemagne',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Allemagne',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1931-03-15',
#   'year': 1931.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9de'),
#   'full_date': '14 mai 1931',
#   'match': 'France - Angleterre',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 5,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1931-05-14',
#   'year': 1931.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9df'),
#   'full_date': '29 novembre 1931',
#   'match': 'France - Pays-Bas',
#   'score': '3-4',
#   'type': 'Match amical',
#   'adversaire': 'Pays-Bas',
#   'score_france': 3,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1931-11-29',
#   'year': 1931.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e0'),
#   'full_date': '20 mars 1932',
#   'match': 'Suisse - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-03-20',
#   'year': 1932.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e1'),
#   'full_date': '10 avril 1932',
#   'match': 'France - Italie',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-04-10',
#   'year': 1932.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e2'),
#   'full_date': '1er mai 1932',
#   'match': 'Belgique - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-05-01',
#   'year': 1932.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e3'),
#   'full_date': '8 mai 1932',
#   'match': 'France - Ã\x89cosse',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-05-08',
#   'year': 1932.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e4'),
#   'full_date': '5 juin 1932',
#   'match': 'Royaume de Yougoslavie - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Royaume de Yougoslavie',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-06-05',
#   'year': 1932.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e5'),
#   'full_date': '9 juin 1932',
#   'match': 'Bulgarie - France',
#   'score': '3-5',
#   'type': 'Match amical',
#   'adversaire': 'Bulgarie',
#   'score_france': 5,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-06-09',
#   'year': 1932.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e6'),
#   'full_date': '12 juin 1932',
#   'match': 'Roumanie - France',
#   'score': '6-3',
#   'type': 'Match amical',
#   'adversaire': 'Roumanie',
#   'score_france': 3,
#   'score_adversaire': 6,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1932-06-12',
#   'year': 1932.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e7'),
#   'full_date': '12 fÃ©vrier 1933',
#   'match': 'France - Autriche',
#   'score': '0-4',
#   'type': 'Match amical',
#   'adversaire': 'Autriche',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-02-12',
#   'year': 1933.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e8'),
#   'full_date': '19 mars 1933',
#   'match': 'Allemagne - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Allemagne',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-03-19',
#   'year': 1933.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9e9'),
#   'full_date': '26 mars 1933',
#   'match': 'France - Belgique',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-03-26',
#   'year': 1933.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ea'),
#   'full_date': '23 avril 1933',
#   'match': 'France - Espagne',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Espagne',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-04-23',
#   'year': 1933.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9eb'),
#   'full_date': '25 mai 1933',
#   'match': 'France - Pays de Galles',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Pays de Galles',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-05-25',
#   'year': 1933.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ec'),
#   'full_date': '10 juin 1933',
#   'match': 'TchÃ©coslovaquie - France',
#   'score': '4-0',
#   'type': 'Match amical',
#   'adversaire': 'TchÃ©coslovaquie',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-06-10',
#   'year': 1933.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ed'),
#   'full_date': '6 dÃ©cembre 1933',
#   'match': 'Angleterre - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1933-12-06',
#   'year': 1933.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ee'),
#   'full_date': '21 janvier 1934',
#   'match': 'Belgique - France',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-01-21',
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9ef'),
#   'full_date': '11 mars 1934',
#   'match': 'France - Suisse',
#   'score': '0-1',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-03-11',
#   'year': 1934.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f0'),
#   'full_date': '25 mars 1934',
#   'match': 'France - TchÃ©coslovaquie',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'TchÃ©coslovaquie',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-03-25',
#   'year': 1934.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f1'),
#   'full_date': '15 avril 1934',
#   'match': 'Luxembourg - France',
#   'score': '1-6',
#   'type': 'Qualifications pour la Coupe du monde 1934',
#   'adversaire': 'Luxembourg',
#   'score_france': 6,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-04-15',
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f2'),
#   'full_date': '10 mai 1934',
#   'match': 'Pays-Bas - France',
#   'score': '4-5',
#   'type': 'Match amical',
#   'adversaire': 'Pays-Bas',
#   'score_france': 5,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-05-10',
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f3'),
#   'full_date': '27 mai 1934',
#   'match': 'Autriche - France',
#   'score': '3-2',
#   'type': 'Coupe du monde 1934 (HuitiÃ¨me de finale)',
#   'adversaire': 'Autriche',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-05-27',
#   'year': 1934.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f4'),
#   'full_date': '6 dÃ©cembre 1934',
#   'match': 'France - Royaume de Yougoslavie',
#   'score': '3-2',
#   'type': 'Match amical',
#   'adversaire': 'Royaume de Yougoslavie',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1934-12-06',
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f5'),
#   'full_date': '27 janvier 1935',
#   'match': 'Espagne - France',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Espagne',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-01-27',
#   'year': 1935.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f6'),
#   'full_date': '17 fÃ©vrier 1935',
#   'match': 'Italie - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-02-17',
#   'year': 1935.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f7'),
#   'full_date': '17 mars 1935',
#   'match': 'France - Allemagne',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Allemagne',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-03-17',
#   'year': 1935.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f8'),
#   'full_date': '14 avril 1935',
#   'match': 'Belgique - France',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-04-14',
#   'year': 1935.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7c9f9'),
#   'full_date': '19 mai 1935',
#   'match': 'France - Hongrie',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Hongrie',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-05-19',
#   'year': 1935.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7c9fa'),
#   'full_date': '27 octobre 1935',
#   'match': 'Suisse - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Suisse',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-10-27',
#   'year': 1935.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7c9fb'),
#   'full_date': '10 novembre 1935',
#   'match': 'France - SuÃ¨de',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '1935-11-10',
#   'year': 1935.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7c9fc'),
#   'full_date': '12 janvier 1936',
#   'match': 'France - Pays-Bas',
#   'score': '1-6',
#   'type': 'Match amical',
#   'adversaire': 'Pays-Bas',
#   'score_france': 1,
#   'score_adversaire': 6,
#   'penalty_france': nan,
# ...
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-06-07',
#   'year': 2015.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cc90'),
#   'full_date': '13 juin 2015',
#   'match': 'Albanie - France',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Albanie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-06-13',
#   'year': 2015.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cc91'),
#   'full_date': '4 septembre 2015',
#   'match': 'Portugal - France',
#   'score': '0-1',
#   'type': 'Match amical',
#   'adversaire': 'Portugal',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-09-04',
#   'year': 2015.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cc92'),
#   'full_date': '7 septembre 2015',
#   'match': 'France - Serbie',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Serbie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-09-07',
#   'year': 2015.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cc93'),
#   'full_date': '8 octobre 2015',
#   'match': 'France - ArmÃ©nie',
#   'score': '4-0',
#   'type': 'Match amical',
#   'adversaire': 'ArmÃ©nie',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-10-08',
#   'year': 2015.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cc94'),
#   'full_date': '11 octobre 2015',
#   'match': 'Danemark - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Danemark',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-10-11',
#   'year': 2015.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cc95'),
#   'full_date': '13 novembre 2015',
#   'match': 'France - Allemagne',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Allemagne',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-11-13',
#   'year': 2015.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cc96'),
#   'full_date': '17 novembre 2015',
#   'match': 'Angleterre - France',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2015-11-17',
#   'year': 2015.0,
#   'outcome': 'loss',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cc97'),
#   'full_date': '25 mars 2016',
#   'match': 'Pays-Bas - France[76]',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Pays-Bas',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-03-25',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7cc98'),
#   'full_date': '29 mars 2016',
#   'match': 'France - Russie',
#   'score': '4-2',
#   'type': 'Match amical',
#   'adversaire': 'Russie',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-03-29',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7cc99'),
#   'full_date': '30 mai 2016',
#   'match': 'France - Cameroun',
#   'score': '3-2',
#   'type': 'Match amical',
#   'adversaire': 'Cameroun',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-05-30',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7cc9a'),
#   'full_date': '4 juin 2016',
#   'match': 'France - Ã\x89cosse',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-06-04',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7cc9b'),
#   'full_date': '10 juin 2016',
#   'match': 'France - Roumanie',
#   'score': '2-1',
#   'type': 'Euro 2016 (Groupe A)',
#   'adversaire': 'Roumanie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-06-10',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7cc9c'),
#   'full_date': '15 juin 2016',
#   'match': 'France - Albanie',
#   'score': '2-0',
#   'type': 'Euro 2016 (Groupe A)',
#   'adversaire': 'Albanie',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-06-15',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7cc9d'),
#   'full_date': '19 juin 2016',
#   'match': 'Suisse - France',
#   'score': '0-0',
#   'type': 'Euro 2016 (Groupe A)',
#   'adversaire': 'Suisse',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-06-19',
#   'year': 2016.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7cc9e'),
#   'full_date': '26 juin 2016',
#   'match': 'France - Irlande',
#   'score': '2-1',
#   'type': 'Euro 2016 (HuitiÃ¨me de finale)',
#   'adversaire': 'Irlande',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-06-26',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7cc9f'),
#   'full_date': '3 juillet 2016',
#   'match': 'France - Islande',
#   'score': '5-2',
#   'type': 'Euro 2016 (Quart de finale)',
#   'adversaire': 'Islande',
#   'score_france': 5,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-07-03',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7cca0'),
#   'full_date': '7 juillet 2016',
#   'match': 'Allemagne - France',
#   'score': '0-2',
#   'type': 'Euro 2016 (Demi-finale)',
#   'adversaire': 'Allemagne',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-07-07',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7cca1'),
#   'full_date': '10 juillet 2016',
#   'match': 'Portugal - France',
#   'score': '1-0 ap',
#   'type': 'Euro 2016 (Finale)',
#   'adversaire': 'Portugal',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-07-10',
#   'year': 2016.0,
#   'outcome': 'loss',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7cca2'),
#   'full_date': '1er septembre 2016',
#   'match': 'Italie - France',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-09-01',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 12},
#  {'_id': ObjectId('602e86232f5eeac022c7cca3'),
#   'full_date': '6 septembre 2016',
#   'match': 'BiÃ©lorussie - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-09-06',
#   'year': 2016.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602e86232f5eeac022c7cca4'),
#   'full_date': '7 octobre 2016',
#   'match': 'France - Bulgarie',
#   'score': '4-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Bulgarie',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-10-07',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 14},
#  {'_id': ObjectId('602e86232f5eeac022c7cca5'),
#   'full_date': '10 octobre 2016',
#   'match': 'Pays-Bas - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Pays-Bas',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-10-10',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 15},
#  {'_id': ObjectId('602e86232f5eeac022c7cca6'),
#   'full_date': '11 novembre 2016',
#   'match': 'France - SuÃ¨de',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-11-11',
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 16},
#  {'_id': ObjectId('602e86232f5eeac022c7cca7'),
#   'full_date': '15 novembre 2016',
#   'match': "France - CÃ´te d'Ivoire",
#   'score': '0-0',
#   'type': 'Match amical[39]',
#   'adversaire': "CÃ´te d'Ivoire",
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2016-11-15',
#   'year': 2016.0,
#   'outcome': 'draw',
#   'no': 17},
#  {'_id': ObjectId('602e86232f5eeac022c7cca8'),
#   'full_date': '25 mars 2017',
#   'match': 'Luxembourg - France',
#   'score': '1-3',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Luxembourg',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-03-25',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7cca9'),
#   'full_date': '28 mars 2017',
#   'match': 'France - Espagne',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Espagne',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-03-28',
#   'year': 2017.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7ccaa'),
#   'full_date': '2 juin 2017',
#   'match': 'France - Paraguay',
#   'score': '5-0',
#   'type': 'Match amical',
#   'adversaire': 'Paraguay',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-06-02',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ccab'),
#   'full_date': '9 juin 2017',
#   'match': 'SuÃ¨de - France',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-06-09',
#   'year': 2017.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ccac'),
#   'full_date': '13 juin 2017',
#   'match': 'France - Angleterre',
#   'score': '3-2',
#   'type': 'Match amical',
#   'adversaire': 'Angleterre',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-06-13',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ccad'),
#   'full_date': '31 aoÃ»t 2017',
#   'match': 'France - Pays-Bas',
#   'score': '4-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Pays-Bas',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-08-31',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ccae'),
#   'full_date': '3 septembre 2017',
#   'match': 'France - Luxembourg',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Luxembourg',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-09-03',
#   'year': 2017.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ccaf'),
#   'full_date': '7 octobre 2017',
#   'match': 'Bulgarie - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Bulgarie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-10-07',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb0'),
#   'full_date': '10 octobre 2017',
#   'match': 'France - BiÃ©lorussie',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-10-10',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb1'),
#   'full_date': '10 novembre 2017',
#   'match': 'France - Pays de Galles',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Pays de Galles',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-11-10',
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb2'),
#   'full_date': '14 novembre 2017',
#   'match': 'Allemagne - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Allemagne',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2017-11-14',
#   'year': 2017.0,
#   'outcome': 'draw',
#   'no': 11},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb3'),
#   'full_date': '23 mars 2018',
#   'match': 'France - Colombie',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Colombie',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-03-23',
#   'year': 2018.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb4'),
#   'full_date': '27 mars 2018',
#   'match': 'Russie - France',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Russie',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-03-27',
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb5'),
#   'full_date': '28 mai 2018',
#   'match': 'France - Irlande',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Irlande',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-05-28',
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb6'),
#   'full_date': '1er juin 2018',
#   'match': 'France - Italie',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Italie',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-06-01',
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb7'),
#   'full_date': '9 juin 2018',
#   'match': 'France - Ã\x89tats-Unis',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Ã\x89tats-Unis',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-06-09',
#   'year': 2018.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb8'),
#   'full_date': '16 juin 2018',
#   'match': 'France - Australie',
#   'score': '2-1',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'Australie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-06-16',
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602e86232f5eeac022c7ccb9'),
#   'full_date': '21 juin 2018',
#   'match': 'France - PÃ©rou',
#   'score': '1-0',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'PÃ©rou',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-06-21',
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602e86232f5eeac022c7ccba'),
#   'full_date': '26 juin 2018',
#   'match': 'Danemark - France',
#   'score': '0-0',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'Danemark',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': '2018-06-26',
#   'year': 2018.0,
#   'outcome': 'draw',
#   'no': 8}]
