# %% [markdown]
# # PROJET: Liste des matchs de l'équipe de France de 1904 à juin 2018

# %% [markdown]
# ## Aïmen Zemzi / Ryan Daoud

# %% [markdown]
# Bienvenue sur notre jeu de données, la France est considérée comme l'une des meilleures nations de football, en atteste ces deux étoiles remportées en 1998 et en 2018.
# C'est pour cela que nous avons décidé de lister tous les matchs de l'équipe de France de 1904 (sa date de création) à juin 2018.

# %% [markdown]
# Mais avant de vous montrer des données intéressantes que vous pourrez manipuler. Il est nécessaire d'effectuer quelques opérations, d'abord il faut importer les librairies ci dessous qui nous permettrons d'extraire des données spécifiques.

# %%
import numpy as np
import pandas as pd
import pymongo
import datetime

# %% [markdown]
# ### Connexion à la base de données

# %%
client = pymongo.MongoClient("mongodb://test:ryan1999@cluster0-shard-00-00.rcdsg.mongodb.net:27017,cluster0-shard-00-01.rcdsg.mongodb.net:27017,cluster0-shard-00-02.rcdsg.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-b2l3g1-shard-0&authSource=admin&w=majority")
database = client['exercices']
collection = database['projet']

# %% [markdown]
# ### Afficher la table

# %%
df_foot = pd.read_csv("./data/df_matches.csv", encoding = "ISO-8859-1")
df_foot.head(2)
# Out:
#                  X2                 X4   X5            X6 adversaire  \
# 0      1er mai 1904  Belgique - France  3-3  Match amical   Belgique
# 1  12 fÃ©vrier 1905    France - Suisse  1-0  Match amical     Suisse
#
#    score_france  score_adversaire  penalty_france  penalty_adversaire  \
# 0             3                 3             NaN                 NaN
# 1             1                 0             NaN                 NaN
#
#          date    year outcome  no
# 0  1904-05-01  1904.0    draw   1
# 1  1905-02-12  1905.0     win   1

# %% [markdown]
# ### Nettoyer les données

# %%
df_foot.rename(columns={'X2':'full_date'}, inplace=True)
df_foot.rename(columns={'X4':'match'}, inplace=True)
df_foot.rename(columns={'X5':'score'}, inplace=True)
df_foot.rename(columns={'X6':'type'}, inplace=True)
df_foot['date'] = pd.to_datetime(df_foot['date'], errors='coerce')
df_foot = df_foot.dropna(subset=['date'])
df_foot = df_foot.drop_duplicates(subset='date', keep='last')
l_d = df_foot.to_dict(orient='records')
for elt in l_d:
    for k,v in elt.items():
        if v == np.NaN:
            del elt[k]

# %% [markdown]
# ### Importer les données

# %%
collection.delete_many({})
collection.insert_many(l_d)

# %% [markdown]
# Une fois ces opérations effectuées, nous pouvons nous amuser et en savoir plus sur l'équipe de France. Nous avons évoqué précedemment que la France était l'une des meilleures nations de football et cette première reqûete nous le confirme.

# %%
req = collection.find({"outcome":"win"})
print(req.count())
req_two = collection.find({"outcome":"draw"})
print(req_two.count())
req_three = collection.find({"outcome":"loss"})
print(req_three.count())
# Out:
# 408
# 177
# 250

# %% [markdown]
# En sachant que la France comptabilisait 408 victoires en juin 2018. Cela fait un ratio de victoire presque égale à 48% qui contrairement aux apparences est un très bon résultat.

# %% [markdown]
# Maintenant reste à savoir, contre qui la France a performé ou non, pour cela voici une requête qui nous permet de lister toutes les rencontres contre une séléction nationale (Belgique dans l'exemple ci-dessous).

# %%
query = collection.find({"adversaire":"Belgique"})
list(query)
# Out:
# [{'_id': ObjectId('602f75651f9c21001fe15268'),
#   'full_date': '1er mai 1904',
#   'match': 'Belgique - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1904, 5, 1, 0, 0),
#   'year': 1904.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe1526a'),
#   'full_date': '7 mai 1905',
#   'match': 'Belgique - France',
#   'score': '7-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1905, 5, 7, 0, 0),
#   'year': 1905.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe1526b'),
#   'full_date': '22 avril 1906',
#   'match': 'France - Belgique',
#   'score': '0-5',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1906, 4, 22, 0, 0),
#   'year': 1906.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe1526d'),
#   'full_date': '21 avril 1907',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1907, 4, 21, 0, 0),
#   'year': 1907.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15270'),
#   'full_date': '12 avril 1908',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1908, 4, 12, 0, 0),
#   'year': 1908.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15273'),
#   'full_date': '8 mai 1909',
#   'match': 'Belgique - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1909, 5, 8, 0, 0),
#   'year': 1909.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15275'),
#   'full_date': '3 avril 1910',
#   'match': 'France - Belgique',
#   'score': '0-4',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1910, 4, 3, 0, 0),
#   'year': 1910.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe1527c'),
#   'full_date': '30 avril 1911',
#   'match': 'Belgique - France',
#   'score': '7-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 7,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1911, 4, 30, 0, 0),
#   'year': 1911.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe1527e'),
#   'full_date': '28 janvier 1912',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1912, 1, 28, 0, 0),
#   'year': 1912.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15282'),
#   'full_date': '16 fÃ©vrier 1913',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1913, 2, 16, 0, 0),
#   'year': 1913.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe15286'),
#   'full_date': '25 janvier 1914',
#   'match': 'France - Belgique',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1914, 1, 25, 0, 0),
#   'year': 1914.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe1528b'),
#   'full_date': '9 mars 1919',
#   'match': 'Belgique - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1919, 3, 9, 0, 0),
#   'year': 1919.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe1528e'),
#   'full_date': '28 mars 1920',
#   'match': 'France - Belgique',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1920, 3, 28, 0, 0),
#   'year': 1920.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15294'),
#   'full_date': '6 mars 1921',
#   'match': 'Belgique - France',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1921, 3, 6, 0, 0),
#   'year': 1921.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15297'),
#   'full_date': '15 janvier 1922',
#   'match': 'France - Belgique',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1922, 1, 15, 0, 0),
#   'year': 1922.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe1529a'),
#   'full_date': '25 fÃ©vrier 1923',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1923, 2, 25, 0, 0),
#   'year': 1923.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe1529f'),
#   'full_date': '13 janvier 1924',
#   'match': 'France - Belgique',
#   'score': '2-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1924, 1, 13, 0, 0),
#   'year': 1924.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe152a5'),
#   'full_date': '11 novembre 1924',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1924, 11, 11, 0, 0),
#   'year': 1924.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe152a9'),
#   'full_date': '11 avril 1926',
#   'match': 'France - Belgique',
#   'score': '4-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1926, 4, 11, 0, 0),
#   'year': 1926.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe152ae'),
#   'full_date': '20 juin 1926',
#   'match': 'Belgique - France',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1926, 6, 20, 0, 0),
#   'year': 1926.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe152b6'),
#   'full_date': '15 avril 1928',
#   'match': 'France - Belgique',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1928, 4, 15, 0, 0),
#   'year': 1928.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe152c0'),
#   'full_date': '26 mai 1929',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1929, 5, 26, 0, 0),
#   'year': 1929.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe152c3'),
#   'full_date': '13 avril 1930',
#   'match': 'France - Belgique',
#   'score': '1-6',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 6,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1930, 4, 13, 0, 0),
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe152c6'),
#   'full_date': '25 mai 1930',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1930, 5, 25, 0, 0),
#   'year': 1930.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe152ca'),
#   'full_date': '7 dÃ©cembre 1930',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1930, 12, 7, 0, 0),
#   'year': 1930.0,
#   'outcome': 'draw',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe152d2'),
#   'full_date': '1er mai 1932',
#   'match': 'Belgique - France',
#   'score': '5-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1932, 5, 1, 0, 0),
#   'year': 1932.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe152d9'),
#   'full_date': '26 mars 1933',
#   'match': 'France - Belgique',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1933, 3, 26, 0, 0),
#   'year': 1933.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe152de'),
#   'full_date': '21 janvier 1934',
#   'match': 'Belgique - France',
#   'score': '2-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1934, 1, 21, 0, 0),
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe152e8'),
#   'full_date': '14 avril 1935',
#   'match': 'Belgique - France',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1935, 4, 14, 0, 0),
#   'year': 1935.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe152ee'),
#   'full_date': '8 mars 1936',
#   'match': 'France - Belgique',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1936, 3, 8, 0, 0),
#   'year': 1936.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe152f1'),
#   'full_date': '21 fÃ©vrier 1937',
#   'match': 'Belgique - France',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1937, 2, 21, 0, 0),
#   'year': 1937.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe152f7'),
#   'full_date': '30 janvier 1938',
#   'match': 'France - Belgique',
#   'score': '5-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 5,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1938, 1, 30, 0, 0),
#   'year': 1938.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe152fa'),
#   'full_date': '5 juin 1938',
#   'match': 'France - Belgique',
#   'score': '3-1',
#   'type': 'Coupe du monde 1938 (HuitiÃ¨me de finale)',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1938, 6, 5, 0, 0),
#   'year': 1938.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe152ff'),
#   'full_date': '18 mai 1939',
#   'match': 'Belgique - France',
#   'score': '1-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1939, 5, 18, 0, 0),
#   'year': 1939.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15304'),
#   'full_date': '24 dÃ©cembre 1944',
#   'match': 'France - Belgique',
#   'score': '3-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1944, 12, 24, 0, 0),
#   'year': 1944.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15308'),
#   'full_date': '15 dÃ©cembre 1945',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1945, 12, 15, 0, 0),
#   'year': 1945.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15310'),
#   'full_date': '1er juin 1947',
#   'match': 'France - Belgique',
#   'score': '4-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1947, 6, 1, 0, 0),
#   'year': 1947.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15315'),
#   'full_date': '6 juin 1948',
#   'match': 'Belgique - France',
#   'score': '4-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1948, 6, 6, 0, 0),
#   'year': 1948.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15317'),
#   'full_date': '17 octobre 1948',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1948, 10, 17, 0, 0),
#   'year': 1948.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15322'),
#   'full_date': '4 juin 1950',
#   'match': 'Belgique - France',
#   'score': '4-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1950, 6, 4, 0, 0),
#   'year': 1950.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe15323'),
#   'full_date': '1er novembre 1950',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1950, 11, 1, 0, 0),
#   'year': 1950.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe1532e'),
#   'full_date': '22 mai 1952',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1952, 5, 22, 0, 0),
#   'year': 1952.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15333'),
#   'full_date': '25 dÃ©cembre 1952',
#   'match': 'France - Belgique',
#   'score': '0-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1952, 12, 25, 0, 0),
#   'year': 1952.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe1533d'),
#   'full_date': '30 mai 1954',
#   'match': 'Belgique - France',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1954, 5, 30, 0, 0),
#   'year': 1954.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe15341'),
#   'full_date': '11 novembre 1954',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1954, 11, 11, 0, 0),
#   'year': 1954.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15348'),
#   'full_date': '25 dÃ©cembre 1955',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1955, 12, 25, 0, 0),
#   'year': 1955.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe1534d'),
#   'full_date': '11 novembre 1956',
#   'match': 'France - Belgique',
#   'score': '6-3',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 6,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1956, 11, 11, 0, 0),
#   'year': 1956.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15352'),
#   'full_date': '27 octobre 1957',
#   'match': 'Belgique - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1957, 10, 27, 0, 0),
#   'year': 1957.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15362'),
#   'full_date': '1er mars 1959',
#   'match': 'France - Belgique',
#   'score': '2-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1959, 3, 1, 0, 0),
#   'year': 1959.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15367'),
#   'full_date': '28 fÃ©vrier 1960',
#   'match': 'Belgique - France',
#   'score': '1-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1960, 2, 28, 0, 0),
#   'year': 1960.0,
#   'outcome': 'loss',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15371'),
#   'full_date': '15 mars 1961',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1961, 3, 15, 0, 0),
#   'year': 1961.0,
#   'outcome': 'draw',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15374'),
#   'full_date': '18 octobre 1961',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1961, 10, 18, 0, 0),
#   'year': 1961.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15384'),
#   'full_date': '25 dÃ©cembre 1963',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1963, 12, 25, 0, 0),
#   'year': 1963.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe15389'),
#   'full_date': '2 dÃ©cembre 1964',
#   'match': 'Belgique - France',
#   'score': '3-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1964, 12, 2, 0, 0),
#   'year': 1964.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15391'),
#   'full_date': '20 avril 1966',
#   'match': 'France - Belgique',
#   'score': '0-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1966, 4, 20, 0, 0),
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe15398'),
#   'full_date': '11 novembre 1966',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': "Qualifications pour l'Euro 1968",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1966, 11, 11, 0, 0),
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe1539e'),
#   'full_date': '28 octobre 1967',
#   'match': 'France - Belgique',
#   'score': '1-1',
#   'type': "Qualifications pour l'Euro 1968",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1967, 10, 28, 0, 0),
#   'year': 1967.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe153b0'),
#   'full_date': '15 novembre 1970',
#   'match': 'Belgique - France',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1970, 11, 15, 0, 0),
#   'year': 1970.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe153cb'),
#   'full_date': '12 octobre 1974',
#   'match': 'Belgique - France',
#   'score': '2-1',
#   'type': "Qualifications pour l'Euro 1976",
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1974, 10, 12, 0, 0),
#   'year': 1974.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe153d2'),
#   'full_date': '15 novembre 1975',
#   'match': 'France - Belgique',
#   'score': '0-0',
#   'type': "Qualifications pour l'Euro 1976",
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1975, 11, 15, 0, 0),
#   'year': 1975.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe153f9'),
#   'full_date': '29 avril 1981',
#   'match': 'France - Belgique',
#   'score': '3-2',
#   'type': 'Qualifications pour la Coupe du monde 1982',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1981, 4, 29, 0, 0),
#   'year': 1981.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe153fb'),
#   'full_date': '9 septembre 1981',
#   'match': 'Belgique - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1982',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1981, 9, 9, 0, 0),
#   'year': 1981.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15411'),
#   'full_date': '31 mai 1983',
#   'match': 'Belgique - France[29]',
#   'score': '1-1',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1983, 5, 31, 0, 0),
#   'year': 1983.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe1541a'),
#   'full_date': '16 juin 1984',
#   'match': 'France - Belgique',
#   'score': '5-0',
#   'type': 'Euro 1984 (Groupe A)',
#   'adversaire': 'Belgique',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1984, 6, 16, 0, 0),
#   'year': 1984.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe1542f'),
#   'full_date': '28 juin 1986',
#   'match': 'France - Belgique',
#   'score': '4-2',
#   'type': 'Coupe du monde 1986 (Petite finale)',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1986, 6, 28, 0, 0),
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe15459'),
#   'full_date': '25 mars 1992',
#   'match': 'France - Belgique',
#   'score': '3-3',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1992, 3, 25, 0, 0),
#   'year': 1992.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe1547f'),
#   'full_date': '27 mars 1996',
#   'match': 'Belgique - France',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1996, 3, 27, 0, 0),
#   'year': 1996.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15497'),
#   'full_date': '27 mai 1998',
#   'match': 'France - Belgique',
#   'score': '1-0',
#   'type': 'Tournoi Hassan II 1998 (amical)',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1998, 5, 27, 0, 0),
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe154d1'),
#   'full_date': '18 mai 2002',
#   'match': 'France - Belgique',
#   'score': '1-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2002, 5, 18, 0, 0),
#   'year': 2002.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe154e9'),
#   'full_date': '18 fÃ©vrier 2004',
#   'match': 'Belgique - France',
#   'score': '0-2',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2004, 2, 18, 0, 0),
#   'year': 2004.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15553'),
#   'full_date': '15 novembre 2011',
#   'match': 'France - Belgique',
#   'score': '0-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2011, 11, 15, 0, 0),
#   'year': 2011.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602f75651f9c21001fe15567'),
#   'full_date': '14 aoÃ»t 2013',
#   'match': 'Belgique - France',
#   'score': '0-0',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2013, 8, 14, 0, 0),
#   'year': 2013.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe1557f'),
#   'full_date': '7 juin 2015',
#   'match': 'France - Belgique',
#   'score': '3-4',
#   'type': 'Match amical',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 4,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2015, 6, 7, 0, 0),
#   'year': 2015.0,
#   'outcome': 'loss',
#   'no': 3}]

# %% [markdown]
# Dans le cas où seulement un époque précise vous intéresse, vous pouvez mettre une date de début et de fin comme dans la reqûete ci-dessous.

# %%
from_date = datetime.datetime(2010, 12, 31, 0, 0, 0)
to_date = datetime.datetime(2018, 12, 31, 23, 59, 59)
for post in collection.find({"$and": [{"adversaire":"Angleterre"}, {"date": {"$gte": from_date, "$lt": to_date}}]}):
    print(post)
# Out:
# {'_id': ObjectId('602f75651f9c21001fe15558'), 'full_date': '11 juin 2012', 'match': 'France - Angleterre', 'score': '1-1', 'type': 'Euro 2012 (Groupe D)', 'adversaire': 'Angleterre', 'score_france': 1, 'score_adversaire': 1, 'penalty_france': nan, 'penalty_adversaire': nan, 'date': datetime.datetime(2012, 6, 11, 0, 0), 'year': 2012.0, 'outcome': 'draw', 'no': 5}
# {'_id': ObjectId('602f75651f9c21001fe15586'), 'full_date': '17 novembre 2015', 'match': 'Angleterre - France', 'score': '2-0', 'type': 'Match amical', 'adversaire': 'Angleterre', 'score_france': 0, 'score_adversaire': 2, 'penalty_france': nan, 'penalty_adversaire': nan, 'date': datetime.datetime(2015, 11, 17, 0, 0), 'year': 2015.0, 'outcome': 'loss', 'no': 10}
# {'_id': ObjectId('602f75651f9c21001fe1559c'), 'full_date': '13 juin 2017', 'match': 'France - Angleterre', 'score': '3-2', 'type': 'Match amical', 'adversaire': 'Angleterre', 'score_france': 3, 'score_adversaire': 2, 'penalty_france': nan, 'penalty_adversaire': nan, 'date': datetime.datetime(2017, 6, 13, 0, 0), 'year': 2017.0, 'outcome': 'win', 'no': 5}

# %% [markdown]
# Vous avez également la possibilité de voir la moyenne de nombre de buts marqués par adversaire ainsi que la moyenne de nombre de buts encaissés par adversaire afin de vous faire une idée sur qui a plus ou moins donné du fil à retordre aux bleux.

# %% [markdown]
# #### Nombres de buts marqués par adversaire

# %%
query = collection.aggregate([{"$group" : {"_id" : "$adversaire", "oppositions_number" : {"$sum" : 1} ,"average_goals_per_game" : {"$avg" : "$score_france"}}}, {"$sort" : { "average_goals_per_game" : -1 }}])
list(query)
# Out:
# [{'_id': 'JamaÃ¯que', 'oppositions_number': 1, 'average_goals_per_game': 8.0},
#  {'_id': 'Lettonie', 'oppositions_number': 1, 'average_goals_per_game': 7.0},
#  {'_id': 'AzerbaÃ¯djan',
#   'oppositions_number': 2,
#   'average_goals_per_game': 6.0},
#  {'_id': 'Malte', 'oppositions_number': 2, 'average_goals_per_game': 5.0},
#  {'_id': 'Nouvelle-ZÃ©lande',
#   'oppositions_number': 1,
#   'average_goals_per_game': 5.0},
#  {'_id': 'Ã\x89gypte', 'oppositions_number': 1, 'average_goals_per_game': 5.0},
#  {'_id': 'CONCACAF', 'oppositions_number': 1, 'average_goals_per_game': 5.0},
#  {'_id': 'SÃ©lection FIFA',
#   'oppositions_number': 1,
#   'average_goals_per_game': 5.0},
#  {'_id': 'Arabie saoudite',
#   'oppositions_number': 1,
#   'average_goals_per_game': 4.0},
#  {'_id': 'Estonie', 'oppositions_number': 1, 'average_goals_per_game': 4.0},
#  {'_id': 'AlgÃ©rie', 'oppositions_number': 1, 'average_goals_per_game': 4.0},
#  {'_id': 'Luxembourg',
#   'oppositions_number': 18,
#   'average_goals_per_game': 3.9444444444444446},
#  {'_id': 'Ã\x8eles FÃ©roÃ©',
#   'oppositions_number': 6,
#   'average_goals_per_game': 3.6666666666666665},
#  {'_id': 'Chypre', 'oppositions_number': 8, 'average_goals_per_game': 3.375},
#  {'_id': 'SlovÃ©nie',
#   'oppositions_number': 3,
#   'average_goals_per_game': 3.3333333333333335},
#  {'_id': 'RF Yougoslavie',
#   'oppositions_number': 1,
#   'average_goals_per_game': 3.0},
#  {'_id': 'CorÃ©e du Sud',
#   'oppositions_number': 3,
#   'average_goals_per_game': 3.0},
#  {'_id': 'Honduras', 'oppositions_number': 1, 'average_goals_per_game': 3.0},
#  {'_id': 'Turquie', 'oppositions_number': 4, 'average_goals_per_game': 3.0},
#  {'_id': 'Islande',
#   'oppositions_number': 12,
#   'average_goals_per_game': 2.9166666666666665},
#  {'_id': 'GrÃ¨ce', 'oppositions_number': 8, 'average_goals_per_game': 2.875},
#  {'_id': 'Paraguay', 'oppositions_number': 5, 'average_goals_per_game': 2.8},
#  {'_id': 'ArmÃ©nie', 'oppositions_number': 5, 'average_goals_per_game': 2.8},
#  {'_id': 'Ã\x89tats-Unis',
#   'oppositions_number': 4,
#   'average_goals_per_game': 2.75},
#  {'_id': 'KoweÃ¯t', 'oppositions_number': 2, 'average_goals_per_game': 2.5},
#  {'_id': 'Costa Rica', 'oppositions_number': 2, 'average_goals_per_game': 2.5},
#  {'_id': 'Australie', 'oppositions_number': 4, 'average_goals_per_game': 2.5},
#  {'_id': 'Royaume des\nSerbes, Croates et SlovÃ¨nes',
#   'oppositions_number': 2,
#   'average_goals_per_game': 2.5},
#  {'_id': 'Maroc', 'oppositions_number': 5, 'average_goals_per_game': 2.4},
#  {'_id': 'Andorre',
#   'oppositions_number': 3,
#   'average_goals_per_game': 2.3333333333333335},
#  {'_id': 'Japon',
#   'oppositions_number': 6,
#   'average_goals_per_game': 2.3333333333333335},
#  {'_id': 'Irlande du Nord',
#   'oppositions_number': 8,
#   'average_goals_per_game': 2.25},
#  {'_id': 'Finlande', 'oppositions_number': 8, 'average_goals_per_game': 2.25},
#  {'_id': 'Chili', 'oppositions_number': 5, 'average_goals_per_game': 2.2},
#  {'_id': 'Pays de Galles',
#   'oppositions_number': 5,
#   'average_goals_per_game': 2.2},
#  {'_id': 'Russie',
#   'oppositions_number': 7,
#   'average_goals_per_game': 2.142857142857143},
#  {'_id': 'Mexique',
#   'oppositions_number': 7,
#   'average_goals_per_game': 2.142857142857143},
#  {'_id': 'Togo', 'oppositions_number': 1, 'average_goals_per_game': 2.0},
#  {'_id': 'Iran', 'oppositions_number': 1, 'average_goals_per_game': 2.0},
#  {'_id': 'Afrique', 'oppositions_number': 1, 'average_goals_per_game': 2.0},
#  {'_id': 'Albanie', 'oppositions_number': 7, 'average_goals_per_game': 2.0},
#  {'_id': 'Portugal', 'oppositions_number': 25, 'average_goals_per_game': 1.96},
#  {'_id': 'RFA',
#   'oppositions_number': 15,
#   'average_goals_per_game': 1.8666666666666667},
#  {'_id': 'Hongrie',
#   'oppositions_number': 22,
#   'average_goals_per_game': 1.8636363636363635},
#  {'_id': 'Croatie', 'oppositions_number': 5, 'average_goals_per_game': 1.8},
#  {'_id': 'Suisse',
#   'oppositions_number': 38,
#   'average_goals_per_game': 1.763157894736842},
#  {'_id': 'Tunisie', 'oppositions_number': 4, 'average_goals_per_game': 1.75},
#  {'_id': 'GÃ©orgie', 'oppositions_number': 4, 'average_goals_per_game': 1.75},
#  {'_id': 'Belgique',
#   'oppositions_number': 73,
#   'average_goals_per_game': 1.7397260273972603},
#  {'_id': 'Pays-Bas',
#   'oppositions_number': 26,
#   'average_goals_per_game': 1.7307692307692308},
#  {'_id': 'Bulgarie',
#   'oppositions_number': 22,
#   'average_goals_per_game': 1.7272727272727273},
#  {'_id': 'Autriche',
#   'oppositions_number': 23,
#   'average_goals_per_game': 1.6956521739130435},
#  {'_id': 'Pologne',
#   'oppositions_number': 16,
#   'average_goals_per_game': 1.6875},
#  {'_id': 'Royaume de Yougoslavie',
#   'oppositions_number': 3,
#   'average_goals_per_game': 1.6666666666666667},
#  {'_id': 'Cameroun',
#   'oppositions_number': 3,
#   'average_goals_per_game': 1.6666666666666667},
#  {'_id': 'IsraÃ«l',
#   'oppositions_number': 9,
#   'average_goals_per_game': 1.6666666666666667},
#  {'_id': 'BiÃ©lorussie',
#   'oppositions_number': 6,
#   'average_goals_per_game': 1.6666666666666667},
#  {'_id': 'Angleterre',
#   'oppositions_number': 41,
#   'average_goals_per_game': 1.6341463414634145},
#  {'_id': 'Serbie', 'oppositions_number': 5, 'average_goals_per_game': 1.6},
#  {'_id': 'Colombie', 'oppositions_number': 5, 'average_goals_per_game': 1.6},
#  {'_id': 'Ukraine',
#   'oppositions_number': 9,
#   'average_goals_per_game': 1.5555555555555556},
#  {'_id': 'Chine', 'oppositions_number': 2, 'average_goals_per_game': 1.5},
#  {'_id': 'Afrique du Sud',
#   'oppositions_number': 4,
#   'average_goals_per_game': 1.5},
#  {'_id': 'Bosnie-HerzÃ©govine',
#   'oppositions_number': 4,
#   'average_goals_per_game': 1.5},
#  {'_id': 'Slovaquie', 'oppositions_number': 4, 'average_goals_per_game': 1.5},
#  {'_id': "CÃ´te d'Ivoire",
#   'oppositions_number': 2,
#   'average_goals_per_game': 1.5},
#  {'_id': 'Italie',
#   'oppositions_number': 38,
#   'average_goals_per_game': 1.4736842105263157},
#  {'_id': 'NorvÃ¨ge',
#   'oppositions_number': 15,
#   'average_goals_per_game': 1.4666666666666666},
#  {'_id': 'TchÃ©coslovaquie',
#   'oppositions_number': 20,
#   'average_goals_per_game': 1.45},
#  {'_id': 'Ã\x89cosse',
#   'oppositions_number': 16,
#   'average_goals_per_game': 1.4375},
#  {'_id': 'Irlande',
#   'oppositions_number': 19,
#   'average_goals_per_game': 1.4210526315789473},
#  {'_id': 'Yougoslavie',
#   'oppositions_number': 20,
#   'average_goals_per_game': 1.4},
#  {'_id': 'SuÃ¨de',
#   'oppositions_number': 21,
#   'average_goals_per_game': 1.380952380952381},
#  {'_id': 'Allemagne',
#   'oppositions_number': 14,
#   'average_goals_per_game': 1.3571428571428572},
#  {'_id': 'Danemark',
#   'oppositions_number': 15,
#   'average_goals_per_game': 1.3333333333333333},
#  {'_id': 'Roumanie',
#   'oppositions_number': 16,
#   'average_goals_per_game': 1.3125},
#  {'_id': 'URSS', 'oppositions_number': 10, 'average_goals_per_game': 1.3},
#  {'_id': 'Lituanie', 'oppositions_number': 4, 'average_goals_per_game': 1.25},
#  {'_id': 'BrÃ©sil', 'oppositions_number': 15, 'average_goals_per_game': 1.2},
#  {'_id': 'RDA',
#   'oppositions_number': 7,
#   'average_goals_per_game': 1.1428571428571428},
#  {'_id': 'Espagne',
#   'oppositions_number': 35,
#   'average_goals_per_game': 1.0571428571428572},
#  {'_id': 'Nigeria', 'oppositions_number': 2, 'average_goals_per_game': 1.0},
#  {'_id': 'RÃ©p. tchÃ¨que',
#   'oppositions_number': 4,
#   'average_goals_per_game': 1.0},
#  {'_id': 'Canada', 'oppositions_number': 1, 'average_goals_per_game': 1.0},
#  {'_id': 'Ã\x89quateur',
#   'oppositions_number': 2,
#   'average_goals_per_game': 1.0},
#  {'_id': 'Argentine',
#   'oppositions_number': 11,
#   'average_goals_per_game': 0.6363636363636364},
#  {'_id': 'Uruguay', 'oppositions_number': 8, 'average_goals_per_game': 0.5},
#  {'_id': 'PÃ©rou', 'oppositions_number': 2, 'average_goals_per_game': 0.5},
#  {'_id': 'SÃ©nÃ©gal', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'URSS- France',
#   'oppositions_number': 2,
#   'average_goals_per_game': 0.0},
#  {'_id': 'Australie- France',
#   'oppositions_number': 1,
#   'average_goals_per_game': 0.0},
#  {'_id': 'France â\x80\x93 Italie',
#   'oppositions_number': 1,
#   'average_goals_per_game': 0.0}]

# %% [markdown]
# #### Nombres de buts encaissés par adversaire

# %%
query = collection.aggregate([{"$group" : {"_id" : "$adversaire", "oppositions_number" : {"$sum" : 1} , "average_goals_per_game" : {"$avg" : "$score_adversaire"}}}, {"$sort" : { "average_goals_per_game" : -1 }}])
list(query)
# Out:
# [{'_id': 'AzerbaÃ¯djan',
#   'oppositions_number': 2,
#   'average_goals_per_game': 5.0},
#  {'_id': 'Angleterre',
#   'oppositions_number': 41,
#   'average_goals_per_game': 2.707317073170732},
#  {'_id': 'Belgique',
#   'oppositions_number': 73,
#   'average_goals_per_game': 2.191780821917808},
#  {'_id': 'Italie',
#   'oppositions_number': 38,
#   'average_goals_per_game': 2.1578947368421053},
#  {'_id': 'Hongrie',
#   'oppositions_number': 22,
#   'average_goals_per_game': 2.1363636363636362},
#  {'_id': 'Pays-Bas',
#   'oppositions_number': 26,
#   'average_goals_per_game': 2.0384615384615383},
#  {'_id': 'Royaume des\nSerbes, Croates et SlovÃ¨nes',
#   'oppositions_number': 2,
#   'average_goals_per_game': 2.0},
#  {'_id': 'RFA',
#   'oppositions_number': 15,
#   'average_goals_per_game': 1.9333333333333333},
#  {'_id': 'Espagne', 'oppositions_number': 35, 'average_goals_per_game': 1.8},
#  {'_id': 'Autriche',
#   'oppositions_number': 23,
#   'average_goals_per_game': 1.7391304347826086},
#  {'_id': 'TchÃ©coslovaquie',
#   'oppositions_number': 20,
#   'average_goals_per_game': 1.7},
#  {'_id': 'BrÃ©sil', 'oppositions_number': 15, 'average_goals_per_game': 1.6},
#  {'_id': 'Colombie', 'oppositions_number': 5, 'average_goals_per_game': 1.6},
#  {'_id': 'Suisse',
#   'oppositions_number': 38,
#   'average_goals_per_game': 1.5789473684210527},
#  {'_id': 'Yougoslavie',
#   'oppositions_number': 20,
#   'average_goals_per_game': 1.55},
#  {'_id': 'URSS', 'oppositions_number': 10, 'average_goals_per_game': 1.5},
#  {'_id': 'URSS- France',
#   'oppositions_number': 2,
#   'average_goals_per_game': 1.5},
#  {'_id': 'Costa Rica', 'oppositions_number': 2, 'average_goals_per_game': 1.5},
#  {'_id': 'Russie',
#   'oppositions_number': 7,
#   'average_goals_per_game': 1.4285714285714286},
#  {'_id': 'Royaume de Yougoslavie',
#   'oppositions_number': 3,
#   'average_goals_per_game': 1.3333333333333333},
#  {'_id': 'RÃ©p. tchÃ¨que',
#   'oppositions_number': 4,
#   'average_goals_per_game': 1.25},
#  {'_id': 'Maroc', 'oppositions_number': 5, 'average_goals_per_game': 1.2},
#  {'_id': 'Bulgarie',
#   'oppositions_number': 22,
#   'average_goals_per_game': 1.1818181818181819},
#  {'_id': 'Portugal', 'oppositions_number': 25, 'average_goals_per_game': 1.16},
#  {'_id': 'Allemagne',
#   'oppositions_number': 14,
#   'average_goals_per_game': 1.1428571428571428},
#  {'_id': 'Argentine',
#   'oppositions_number': 11,
#   'average_goals_per_game': 1.0909090909090908},
#  {'_id': 'AlgÃ©rie', 'oppositions_number': 1, 'average_goals_per_game': 1.0},
#  {'_id': 'BiÃ©lorussie',
#   'oppositions_number': 6,
#   'average_goals_per_game': 1.0},
#  {'_id': 'SuÃ¨de', 'oppositions_number': 21, 'average_goals_per_game': 1.0},
#  {'_id': 'NorvÃ¨ge', 'oppositions_number': 15, 'average_goals_per_game': 1.0},
#  {'_id': 'SÃ©lection FIFA',
#   'oppositions_number': 1,
#   'average_goals_per_game': 1.0},
#  {'_id': 'Chili', 'oppositions_number': 5, 'average_goals_per_game': 1.0},
#  {'_id': 'RDA', 'oppositions_number': 7, 'average_goals_per_game': 1.0},
#  {'_id': 'Pologne', 'oppositions_number': 16, 'average_goals_per_game': 1.0},
#  {'_id': 'Uruguay', 'oppositions_number': 8, 'average_goals_per_game': 1.0},
#  {'_id': 'SÃ©nÃ©gal', 'oppositions_number': 1, 'average_goals_per_game': 1.0},
#  {'_id': 'Chine', 'oppositions_number': 2, 'average_goals_per_game': 1.0},
#  {'_id': 'Cameroun', 'oppositions_number': 3, 'average_goals_per_game': 1.0},
#  {'_id': 'Iran', 'oppositions_number': 1, 'average_goals_per_game': 1.0},
#  {'_id': 'Roumanie', 'oppositions_number': 16, 'average_goals_per_game': 1.0},
#  {'_id': 'CorÃ©e du Sud',
#   'oppositions_number': 3,
#   'average_goals_per_game': 1.0},
#  {'_id': 'Australie- France',
#   'oppositions_number': 1,
#   'average_goals_per_game': 1.0},
#  {'_id': 'Ã\x89cosse',
#   'oppositions_number': 16,
#   'average_goals_per_game': 0.9375},
#  {'_id': 'Irlande',
#   'oppositions_number': 19,
#   'average_goals_per_game': 0.8947368421052632},
#  {'_id': 'GrÃ¨ce', 'oppositions_number': 8, 'average_goals_per_game': 0.875},
#  {'_id': 'Mexique',
#   'oppositions_number': 7,
#   'average_goals_per_game': 0.8571428571428571},
#  {'_id': 'Japon',
#   'oppositions_number': 6,
#   'average_goals_per_game': 0.8333333333333334},
#  {'_id': 'Islande',
#   'oppositions_number': 12,
#   'average_goals_per_game': 0.8333333333333334},
#  {'_id': 'Danemark', 'oppositions_number': 15, 'average_goals_per_game': 0.8},
#  {'_id': 'Pays de Galles',
#   'oppositions_number': 5,
#   'average_goals_per_game': 0.8},
#  {'_id': 'Paraguay', 'oppositions_number': 5, 'average_goals_per_game': 0.8},
#  {'_id': 'Serbie', 'oppositions_number': 5, 'average_goals_per_game': 0.8},
#  {'_id': 'Tunisie', 'oppositions_number': 4, 'average_goals_per_game': 0.75},
#  {'_id': 'Afrique du Sud',
#   'oppositions_number': 4,
#   'average_goals_per_game': 0.75},
#  {'_id': 'Bosnie-HerzÃ©govine',
#   'oppositions_number': 4,
#   'average_goals_per_game': 0.75},
#  {'_id': 'Luxembourg',
#   'oppositions_number': 18,
#   'average_goals_per_game': 0.6666666666666666},
#  {'_id': 'SlovÃ©nie',
#   'oppositions_number': 3,
#   'average_goals_per_game': 0.6666666666666666},
#  {'_id': 'IsraÃ«l',
#   'oppositions_number': 9,
#   'average_goals_per_game': 0.6666666666666666},
#  {'_id': 'Croatie', 'oppositions_number': 5, 'average_goals_per_game': 0.6},
#  {'_id': 'Ukraine',
#   'oppositions_number': 9,
#   'average_goals_per_game': 0.5555555555555556},
#  {'_id': 'Australie', 'oppositions_number': 4, 'average_goals_per_game': 0.5},
#  {'_id': 'Nigeria', 'oppositions_number': 2, 'average_goals_per_game': 0.5},
#  {'_id': 'PÃ©rou', 'oppositions_number': 2, 'average_goals_per_game': 0.5},
#  {'_id': 'Turquie', 'oppositions_number': 4, 'average_goals_per_game': 0.5},
#  {'_id': 'Irlande du Nord',
#   'oppositions_number': 8,
#   'average_goals_per_game': 0.5},
#  {'_id': 'KoweÃ¯t', 'oppositions_number': 2, 'average_goals_per_game': 0.5},
#  {'_id': 'Slovaquie', 'oppositions_number': 4, 'average_goals_per_game': 0.5},
#  {'_id': 'Albanie',
#   'oppositions_number': 7,
#   'average_goals_per_game': 0.42857142857142855},
#  {'_id': 'ArmÃ©nie', 'oppositions_number': 5, 'average_goals_per_game': 0.4},
#  {'_id': 'Finlande', 'oppositions_number': 8, 'average_goals_per_game': 0.375},
#  {'_id': 'GÃ©orgie', 'oppositions_number': 4, 'average_goals_per_game': 0.25},
#  {'_id': 'Ã\x89tats-Unis',
#   'oppositions_number': 4,
#   'average_goals_per_game': 0.25},
#  {'_id': 'Chypre', 'oppositions_number': 8, 'average_goals_per_game': 0.25},
#  {'_id': 'Lituanie', 'oppositions_number': 4, 'average_goals_per_game': 0.0},
#  {'_id': "CÃ´te d'Ivoire",
#   'oppositions_number': 2,
#   'average_goals_per_game': 0.0},
#  {'_id': 'JamaÃ¯que', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'Estonie', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'Ã\x89quateur',
#   'oppositions_number': 2,
#   'average_goals_per_game': 0.0},
#  {'_id': 'Afrique', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'France â\x80\x93 Italie',
#   'oppositions_number': 1,
#   'average_goals_per_game': 0.0},
#  {'_id': 'Honduras', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'Lettonie', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'Arabie saoudite',
#   'oppositions_number': 1,
#   'average_goals_per_game': 0.0},
#  {'_id': 'Ã\x8eles FÃ©roÃ©',
#   'oppositions_number': 6,
#   'average_goals_per_game': 0.0},
#  {'_id': 'Malte', 'oppositions_number': 2, 'average_goals_per_game': 0.0},
#  {'_id': 'RF Yougoslavie',
#   'oppositions_number': 1,
#   'average_goals_per_game': 0.0},
#  {'_id': 'Andorre', 'oppositions_number': 3, 'average_goals_per_game': 0.0},
#  {'_id': 'Nouvelle-ZÃ©lande',
#   'oppositions_number': 1,
#   'average_goals_per_game': 0.0},
#  {'_id': 'Ã\x89gypte', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'Togo', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'CONCACAF', 'oppositions_number': 1, 'average_goals_per_game': 0.0},
#  {'_id': 'Canada', 'oppositions_number': 1, 'average_goals_per_game': 0.0}]

# %% [markdown]
# Si les matchs amicaux ne vous intéressent pas comme plus de la moitié des fans de football, il est possible dans cette reqûete de filtrer par type de rencontre, dans l'exemple ci dessous nous avons mit "Coupe du monde" pour lister tous les matchs en rapport avec cette compétition.

# %%
collection.create_index([("type", "text")])
query = collection.find({"$text": {'$search':'Coupe du monde'}}).sort([("year", -1)])
list(query)
# Out:
# [{'_id': ObjectId('602f75651f9c21001fe155aa'),
#   'full_date': '26 juin 2018',
#   'match': 'Danemark - France',
#   'score': '0-0',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'Danemark',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2018, 6, 26, 0, 0),
#   'year': 2018.0,
#   'outcome': 'draw',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe155a9'),
#   'full_date': '21 juin 2018',
#   'match': 'France - PÃ©rou',
#   'score': '1-0',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'PÃ©rou',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2018, 6, 21, 0, 0),
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe155a8'),
#   'full_date': '16 juin 2018',
#   'match': 'France - Australie',
#   'score': '2-1',
#   'type': 'Coupe du monde 2018 (Groupe C)',
#   'adversaire': 'Australie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2018, 6, 16, 0, 0),
#   'year': 2018.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe155a0'),
#   'full_date': '10 octobre 2017',
#   'match': 'France - BiÃ©lorussie',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2017, 10, 10, 0, 0),
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe1559f'),
#   'full_date': '7 octobre 2017',
#   'match': 'Bulgarie - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Bulgarie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2017, 10, 7, 0, 0),
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe1559e'),
#   'full_date': '3 septembre 2017',
#   'match': 'France - Luxembourg',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Luxembourg',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2017, 9, 3, 0, 0),
#   'year': 2017.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe1559d'),
#   'full_date': '31 aoÃ»t 2017',
#   'match': 'France - Pays-Bas',
#   'score': '4-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Pays-Bas',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2017, 8, 31, 0, 0),
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe1559b'),
#   'full_date': '9 juin 2017',
#   'match': 'SuÃ¨de - France',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2017, 6, 9, 0, 0),
#   'year': 2017.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15598'),
#   'full_date': '25 mars 2017',
#   'match': 'Luxembourg - France',
#   'score': '1-3',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Luxembourg',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2017, 3, 25, 0, 0),
#   'year': 2017.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15596'),
#   'full_date': '11 novembre 2016',
#   'match': 'France - SuÃ¨de',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2016, 11, 11, 0, 0),
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 16},
#  {'_id': ObjectId('602f75651f9c21001fe15595'),
#   'full_date': '10 octobre 2016',
#   'match': 'Pays-Bas - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Pays-Bas',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2016, 10, 10, 0, 0),
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 15},
#  {'_id': ObjectId('602f75651f9c21001fe15594'),
#   'full_date': '7 octobre 2016',
#   'match': 'France - Bulgarie',
#   'score': '4-1',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'Bulgarie',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2016, 10, 7, 0, 0),
#   'year': 2016.0,
#   'outcome': 'win',
#   'no': 14},
#  {'_id': ObjectId('602f75651f9c21001fe15593'),
#   'full_date': '6 septembre 2016',
#   'match': 'BiÃ©lorussie - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2018',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2016, 9, 6, 0, 0),
#   'year': 2016.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602f75651f9c21001fe15574'),
#   'full_date': '25 juin 2014',
#   'match': 'Ã\x89quateur - France',
#   'score': '0-0',
#   'type': 'Coupe du monde 2014 (Groupe E)',
#   'adversaire': 'Ã\x89quateur',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2014, 6, 25, 0, 0),
#   'year': 2014.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15573'),
#   'full_date': '20 juin 2014',
#   'match': 'Suisse - France',
#   'score': '2-5',
#   'type': 'Coupe du monde 2014 (Groupe E)',
#   'adversaire': 'Suisse',
#   'score_france': 5,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2014, 6, 20, 0, 0),
#   'year': 2014.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15572'),
#   'full_date': '15 juin 2014',
#   'match': 'France - Honduras',
#   'score': '3-0',
#   'type': 'Coupe du monde 2014 (Groupe E)',
#   'adversaire': 'Honduras',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2014, 6, 15, 0, 0),
#   'year': 2014.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15576'),
#   'full_date': '4 juillet 2014',
#   'match': 'France - Allemagne',
#   'score': '0-1',
#   'type': 'Coupe du monde 2014 (Quart de finale)',
#   'adversaire': 'Allemagne',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2014, 7, 4, 0, 0),
#   'year': 2014.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe15575'),
#   'full_date': '30 juin 2014',
#   'match': 'France - Nigeria',
#   'score': '2-0',
#   'type': 'Coupe du monde 2014 (HuitiÃ¨me de finale)',
#   'adversaire': 'Nigeria',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2014, 6, 30, 0, 0),
#   'year': 2014.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe1556b'),
#   'full_date': '15 octobre 2013',
#   'match': 'France - Finlande',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'Finlande',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2013, 10, 15, 0, 0),
#   'year': 2013.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe15569'),
#   'full_date': '10 septembre 2013',
#   'match': 'BiÃ©lorussie - France',
#   'score': '2-4',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2013, 9, 10, 0, 0),
#   'year': 2013.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe15568'),
#   'full_date': '6 septembre 2013',
#   'match': 'GÃ©orgie - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'GÃ©orgie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2013, 9, 6, 0, 0),
#   'year': 2013.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15564'),
#   'full_date': '26 mars 2013',
#   'match': 'France - Espagne',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'Espagne',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2013, 3, 26, 0, 0),
#   'year': 2013.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15563'),
#   'full_date': '22 mars 2013',
#   'match': 'France - GÃ©orgie',
#   'score': '3-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'GÃ©orgie',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2013, 3, 22, 0, 0),
#   'year': 2013.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe1556d'),
#   'full_date': '19 novembre 2013',
#   'match': 'France - Ukraine',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 2014 (Barrage retour)',
#   'adversaire': 'Ukraine',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2013, 11, 19, 0, 0),
#   'year': 2013.0,
#   'outcome': 'win',
#   'no': 12},
#  {'_id': ObjectId('602f75651f9c21001fe1556c'),
#   'full_date': '15 novembre 2013',
#   'match': 'Ukraine - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 2014 (Barrage aller)',
#   'adversaire': 'Ukraine',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2013, 11, 15, 0, 0),
#   'year': 2013.0,
#   'outcome': 'loss',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe15560'),
#   'full_date': '16 octobre 2012',
#   'match': 'Espagne - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'Espagne',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2012, 10, 16, 0, 0),
#   'year': 2012.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602f75651f9c21001fe1555e'),
#   'full_date': '11 septembre 2012',
#   'match': 'France - BiÃ©lorussie',
#   'score': '3-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'BiÃ©lorussie',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2012, 9, 11, 0, 0),
#   'year': 2012.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe1555d'),
#   'full_date': '7 septembre 2012',
#   'match': 'Finlande - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2014',
#   'adversaire': 'Finlande',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2012, 9, 7, 0, 0),
#   'year': 2012.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe15540'),
#   'full_date': '22 juin 2010',
#   'match': 'France - Afrique du Sud',
#   'score': '1-2',
#   'type': 'Coupe du monde 2010 (Groupe A)',
#   'adversaire': 'Afrique du Sud',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2010, 6, 22, 0, 0),
#   'year': 2010.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe1553f'),
#   'full_date': '17 juin 2010',
#   'match': 'France - Mexique',
#   'score': '0-2',
#   'type': 'Coupe du monde 2010 (Groupe A)',
#   'adversaire': 'Mexique',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2010, 6, 17, 0, 0),
#   'year': 2010.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe1553e'),
#   'full_date': '11 juin 2010',
#   'match': 'Uruguay - France',
#   'score': '0-0',
#   'type': 'Coupe du monde 2010 (Groupe A)',
#   'adversaire': 'Uruguay',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2010, 6, 11, 0, 0),
#   'year': 2010.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15537'),
#   'full_date': '14 octobre 2009',
#   'match': 'France - Autriche',
#   'score': '3-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Autriche',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 10, 14, 0, 0),
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe15536'),
#   'full_date': '10 octobre 2009',
#   'match': 'France - Ã\x8eles FÃ©roÃ©',
#   'score': '5-0',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Ã\x8eles FÃ©roÃ©',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 10, 10, 0, 0),
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe15535'),
#   'full_date': '9 septembre 2009',
#   'match': 'Serbie - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Serbie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 9, 9, 0, 0),
#   'year': 2009.0,
#   'outcome': 'draw',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe15534'),
#   'full_date': '5 septembre 2009',
#   'match': 'France - Roumanie',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Roumanie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 9, 5, 0, 0),
#   'year': 2009.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15533'),
#   'full_date': '12 aoÃ»t 2009',
#   'match': 'Ã\x8eles FÃ©roÃ© - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Ã\x8eles FÃ©roÃ©',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 8, 12, 0, 0),
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15530'),
#   'full_date': '1er avril 2009',
#   'match': 'France - Lituanie',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Lituanie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 4, 1, 0, 0),
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe1552f'),
#   'full_date': '28 mars 2009',
#   'match': 'Lituanie - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Lituanie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 3, 28, 0, 0),
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe15539'),
#   'full_date': '18 novembre 2009',
#   'match': 'France - Irlande',
#   'score': '1-1 ap',
#   'type': 'Qualifications pour la Coupe du monde 2010 (Barrage retour)',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 11, 18, 0, 0),
#   'year': 2009.0,
#   'outcome': 'draw',
#   'no': 12},
#  {'_id': ObjectId('602f75651f9c21001fe15538'),
#   'full_date': '14 novembre 2009',
#   'match': 'Irlande - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2010 (Barrage aller)',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2009, 11, 14, 0, 0),
#   'year': 2009.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe1552b'),
#   'full_date': '11 octobre 2008',
#   'match': 'Roumanie - France',
#   'score': '2-2',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Roumanie',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2008, 10, 11, 0, 0),
#   'year': 2008.0,
#   'outcome': 'draw',
#   'no': 12},
#  {'_id': ObjectId('602f75651f9c21001fe1552a'),
#   'full_date': '10 septembre 2008',
#   'match': 'France - Serbie',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Serbie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2008, 9, 10, 0, 0),
#   'year': 2008.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe15529'),
#   'full_date': '6 septembre 2008',
#   'match': 'Autriche - France',
#   'score': '3-1',
#   'type': 'Qualifications pour la Coupe du monde 2010',
#   'adversaire': 'Autriche',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2008, 9, 6, 0, 0),
#   'year': 2008.0,
#   'outcome': 'loss',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe1550d'),
#   'full_date': '9 juillet 2006',
#   'match': 'Italie - France',
#   'score': '1-1 ap(5-3) tab',
#   'type': 'Coupe du monde 2006 (Finale)',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': 3.0,
#   'penalty_adversaire': 5.0,
#   'date': datetime.datetime(2006, 7, 9, 0, 0),
#   'year': 2006.0,
#   'outcome': 'draw',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe1550c'),
#   'full_date': '5 juillet 2006',
#   'match': 'Portugal - France',
#   'score': '0-1',
#   'type': 'Coupe du monde 2006 (Demi-finale)',
#   'adversaire': 'Portugal',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2006, 7, 5, 0, 0),
#   'year': 2006.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe15509'),
#   'full_date': '23 juin 2006',
#   'match': 'Togo - France',
#   'score': '0-2',
#   'type': 'Coupe du monde 2006 (Groupe G)',
#   'adversaire': 'Togo',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2006, 6, 23, 0, 0),
#   'year': 2006.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15508'),
#   'full_date': '18 juin 2006',
#   'match': 'France - CorÃ©e du Sud',
#   'score': '1-1',
#   'type': 'Coupe du monde 2006 (Groupe G)',
#   'adversaire': 'CorÃ©e du Sud',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2006, 6, 18, 0, 0),
#   'year': 2006.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15507'),
#   'full_date': '13 juin 2006',
#   'match': 'France - Suisse',
#   'score': '0-0',
#   'type': 'Coupe du monde 2006 (Groupe G)',
#   'adversaire': 'Suisse',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2006, 6, 13, 0, 0),
#   'year': 2006.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe1550b'),
#   'full_date': '1er juillet 2006',
#   'match': 'France - BrÃ©sil',
#   'score': '1-0',
#   'type': 'Coupe du monde 2006 (Quart de finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2006, 7, 1, 0, 0),
#   'year': 2006.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe1550a'),
#   'full_date': '27 juin 2006',
#   'match': 'Espagne - France',
#   'score': '1-3',
#   'type': 'Coupe du monde 2006 (HuitiÃ¨me de finale)',
#   'adversaire': 'Espagne',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2006, 6, 27, 0, 0),
#   'year': 2006.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe15500'),
#   'full_date': '12 octobre 2005',
#   'match': 'France - Chypre',
#   'score': '4-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Chypre',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2005, 10, 12, 0, 0),
#   'year': 2005.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe154ff'),
#   'full_date': '8 octobre 2005',
#   'match': 'Suisse - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Suisse',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2005, 10, 8, 0, 0),
#   'year': 2005.0,
#   'outcome': 'draw',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe154fe'),
#   'full_date': '7 septembre 2005',
#   'match': 'Irlande - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2005, 9, 7, 0, 0),
#   'year': 2005.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe154fd'),
#   'full_date': '3 septembre 2005',
#   'match': 'France - Ã\x8eles FÃ©roÃ©',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Ã\x8eles FÃ©roÃ©',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2005, 9, 3, 0, 0),
#   'year': 2005.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe154fa'),
#   'full_date': '29 mars 2005',
#   'match': 'IsraÃ«l - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'IsraÃ«l',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2005, 3, 29, 0, 0),
#   'year': 2005.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe154f9'),
#   'full_date': '26 mars 2005',
#   'match': 'France - Suisse',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Suisse',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2005, 3, 26, 0, 0),
#   'year': 2005.0,
#   'outcome': 'draw',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe154f6'),
#   'full_date': '13 octobre 2004',
#   'match': 'Chypre - France',
#   'score': '0-2',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Chypre',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2004, 10, 13, 0, 0),
#   'year': 2004.0,
#   'outcome': 'win',
#   'no': 14},
#  {'_id': ObjectId('602f75651f9c21001fe154f5'),
#   'full_date': '9 octobre 2004',
#   'match': 'France - Irlande',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Irlande',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2004, 10, 9, 0, 0),
#   'year': 2004.0,
#   'outcome': 'draw',
#   'no': 13},
#  {'_id': ObjectId('602f75651f9c21001fe154f4'),
#   'full_date': '8 septembre 2004',
#   'match': 'Ã\x8eles FÃ©roÃ© - France',
#   'score': '0-2',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'Ã\x8eles FÃ©roÃ©',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2004, 9, 8, 0, 0),
#   'year': 2004.0,
#   'outcome': 'win',
#   'no': 12},
#  {'_id': ObjectId('602f75651f9c21001fe154f3'),
#   'full_date': '4 septembre 2004',
#   'match': 'France - IsraÃ«l',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 2006',
#   'adversaire': 'IsraÃ«l',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2004, 9, 4, 0, 0),
#   'year': 2004.0,
#   'outcome': 'draw',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe154e3'),
#   'full_date': '29 juin 2003',
#   'match': 'France - Cameroun',
#   'score': '1-0 apb.e.o.',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Finale)',
#   'adversaire': 'Cameroun',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2003, 6, 29, 0, 0),
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe154e1'),
#   'full_date': '22 juin 2003',
#   'match': 'France - Nouvelle-ZÃ©lande',
#   'score': '5-0',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Groupe A)',
#   'adversaire': 'Nouvelle-ZÃ©lande',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2003, 6, 22, 0, 0),
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe154e0'),
#   'full_date': '20 juin 2003',
#   'match': 'France - Japon',
#   'score': '2-1',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Groupe A)',
#   'adversaire': 'Japon',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2003, 6, 20, 0, 0),
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe154df'),
#   'full_date': '18 juin 2003',
#   'match': 'France - Colombie',
#   'score': '1-0',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Groupe A)',
#   'adversaire': 'Colombie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2003, 6, 18, 0, 0),
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe154e2'),
#   'full_date': '26 juin 2003',
#   'match': 'France - Turquie',
#   'score': '3-2',
#   'type': 'Coupe des confÃ©dÃ©rations 2003 (Demi-finale)',
#   'adversaire': 'Turquie',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2003, 6, 26, 0, 0),
#   'year': 2003.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe154d5'),
#   'full_date': '11 juin 2002',
#   'match': 'Danemark - France',
#   'score': '2-0',
#   'type': 'Coupe du monde 2002 (Groupe A)',
#   'adversaire': 'Danemark',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2002, 6, 11, 0, 0),
#   'year': 2002.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe154d4'),
#   'full_date': '6 juin 2002',
#   'match': 'France - Uruguay',
#   'score': '0-0',
#   'type': 'Coupe du monde 2002 (Groupe A)',
#   'adversaire': 'Uruguay',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2002, 6, 6, 0, 0),
#   'year': 2002.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe154d3'),
#   'full_date': '31 mai 2002',
#   'match': 'France - SÃ©nÃ©gal',
#   'score': '0-1',
#   'type': 'Coupe du monde 2002 (Groupe A)',
#   'adversaire': 'SÃ©nÃ©gal',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2002, 5, 31, 0, 0),
#   'year': 2002.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe154c9'),
#   'full_date': '10 juin 2001',
#   'match': 'Japon - France',
#   'score': '0-1',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Finale)',
#   'adversaire': 'Japon',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2001, 6, 10, 0, 0),
#   'year': 2001.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe154c7'),
#   'full_date': '3 juin 2001',
#   'match': 'France - Mexique',
#   'score': '4-0',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Groupe A)',
#   'adversaire': 'Mexique',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2001, 6, 3, 0, 0),
#   'year': 2001.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe154c6'),
#   'full_date': '1er juin 2001',
#   'match': 'Australie- France',
#   'score': '1-0',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Groupe A)',
#   'adversaire': 'Australie- France',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2001, 6, 1, 0, 0),
#   'year': 2001.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe154c8'),
#   'full_date': '7 juin 2001',
#   'match': 'France - BrÃ©sil',
#   'score': '2-1',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Demi-finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2001, 6, 7, 0, 0),
#   'year': 2001.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe154c5'),
#   'full_date': '30 mai 2001',
#   'match': 'CorÃ©e du Sud - France',
#   'score': '0-5',
#   'type': 'Coupe des confÃ©dÃ©rations 2001 (Groupe A)[36]',
#   'adversaire': 'CorÃ©e du Sud',
#   'score_france': 5,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2001, 5, 30, 0, 0),
#   'year': 2001.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe154bf'),
#   'full_date': '7 octobre 2000',
#   'match': 'Afrique du Sud - France',
#   'score': '0-0[1]',
#   'type': 'Coupe du challenge 2000[2] (amical)',
#   'adversaire': 'Afrique du Sud',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(2000, 10, 7, 0, 0),
#   'year': 2000.0,
#   'outcome': 'draw',
#   'no': 16},
#  {'_id': ObjectId('602f75651f9c21001fe154a0'),
#   'full_date': '12 juillet 1998',
#   'match': 'BrÃ©sil - France',
#   'score': '0-3',
#   'type': 'Coupe du monde 1998 (Finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1998, 7, 12, 0, 0),
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 14},
#  {'_id': ObjectId('602f75651f9c21001fe1549f'),
#   'full_date': '8 juillet 1998',
#   'match': 'France - Croatie',
#   'score': '2-1',
#   'type': 'Coupe du monde 1998 (Demi-finale)',
#   'adversaire': 'Croatie',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1998, 7, 8, 0, 0),
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 13},
#  {'_id': ObjectId('602f75651f9c21001fe1549c'),
#   'full_date': '24 juin 1998',
#   'match': 'France - Danemark',
#   'score': '2-1',
#   'type': 'Coupe du monde 1998 (Groupe C)',
#   'adversaire': 'Danemark',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1998, 6, 24, 0, 0),
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe1549b'),
#   'full_date': '18 juin 1998',
#   'match': 'France - Arabie saoudite',
#   'score': '4-0',
#   'type': 'Coupe du monde 1998 (Groupe C)',
#   'adversaire': 'Arabie saoudite',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1998, 6, 18, 0, 0),
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe1549a'),
#   'full_date': '12 juin 1998',
#   'match': 'France - Afrique du Sud',
#   'score': '3-0',
#   'type': 'Coupe du monde 1998 (Groupe C)',
#   'adversaire': 'Afrique du Sud',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1998, 6, 12, 0, 0),
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe1549e'),
#   'full_date': '3 juillet 1998',
#   'match': 'France â\x80\x93 Italie',
#   'score': '0-0 ap(4-3) tab',
#   'type': 'Coupe du monde 1998 (Quart de finale)',
#   'adversaire': 'France â\x80\x93 Italie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 3.0,
#   'date': datetime.datetime(1998, 7, 3, 0, 0),
#   'year': 1998.0,
#   'outcome': 'draw',
#   'no': 12},
#  {'_id': ObjectId('602f75651f9c21001fe1549d'),
#   'full_date': '28 juin 1998',
#   'match': 'France - Paraguay',
#   'score': '1-0 apb.e.o.',
#   'type': 'Coupe du monde 1998 (HuitiÃ¨me de finale)',
#   'adversaire': 'Paraguay',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1998, 6, 28, 0, 0),
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe15493'),
#   'full_date': '28 janvier 1998',
#   'match': 'France - Espagne',
#   'score': '1-0',
#   'type': 'Match amical (Inauguration du Stade de France)',
#   'adversaire': 'Espagne',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1998, 1, 28, 0, 0),
#   'year': 1998.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe1546f'),
#   'full_date': '29 mai 1994',
#   'match': 'Japon - France',
#   'score': '1-4',
#   'type': 'Coupe Kirin 1994 (Amical)',
#   'adversaire': 'Japon',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1994, 5, 29, 0, 0),
#   'year': 1994.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe1546e'),
#   'full_date': '26 mai 1994',
#   'match': 'France - Australie',
#   'score': '1-0',
#   'type': 'Coupe Kirin 1994 (Amical)',
#   'adversaire': 'Australie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1994, 5, 26, 0, 0),
#   'year': 1994.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe1546b'),
#   'full_date': '17 novembre 1993',
#   'match': 'France - Bulgarie',
#   'score': '1-2',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Bulgarie',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1993, 11, 17, 0, 0),
#   'year': 1993.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe1546a'),
#   'full_date': '13 octobre 1993',
#   'match': 'France - IsraÃ«l',
#   'score': '2-3',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'IsraÃ«l',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1993, 10, 13, 0, 0),
#   'year': 1993.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe15469'),
#   'full_date': '8 septembre 1993',
#   'match': 'Finlande - France',
#   'score': '0-2',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Finlande',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1993, 9, 8, 0, 0),
#   'year': 1993.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15468'),
#   'full_date': '22 aoÃ»t 1993',
#   'match': 'SuÃ¨de - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1993, 8, 22, 0, 0),
#   'year': 1993.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15465'),
#   'full_date': '28 avril 1993',
#   'match': 'France - SuÃ¨de',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'SuÃ¨de',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1993, 4, 28, 0, 0),
#   'year': 1993.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15464'),
#   'full_date': '27 mars 1993',
#   'match': 'Autriche - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Autriche',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1993, 3, 27, 0, 0),
#   'year': 1993.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe15463'),
#   'full_date': '17 fÃ©vrier 1993',
#   'match': 'IsraÃ«l - France',
#   'score': '0-4',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'IsraÃ«l',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1993, 2, 17, 0, 0),
#   'year': 1993.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15466'),
#   'full_date': '16 juin 1993',
#   'match': 'France - Colombie',
#   'score': '1-3',
#   'type': 'Match amical (Inauguration du Stade de Dillon)',
#   'adversaire': 'Colombie',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1993, 6, 16, 0, 0),
#   'year': 1993.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15462'),
#   'full_date': '14 novembre 1992',
#   'match': 'France - Finlande',
#   'score': '2-1',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Finlande',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1992, 11, 14, 0, 0),
#   'year': 1992.0,
#   'outcome': 'win',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe15461'),
#   'full_date': '14 octobre 1992',
#   'match': 'France - Autriche',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Autriche',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1992, 10, 14, 0, 0),
#   'year': 1992.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe15460'),
#   'full_date': '9 septembre 1992',
#   'match': 'Bulgarie - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1994',
#   'adversaire': 'Bulgarie',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1992, 9, 9, 0, 0),
#   'year': 1992.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe1544b'),
#   'full_date': '24 janvier 1990',
#   'match': 'France - RDA',
#   'score': '3-0',
#   'type': 'Tournoi du KoweÃ¯t 1990 (amical)',
#   'adversaire': 'RDA',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1990, 1, 24, 0, 0),
#   'year': 1990.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe1544a'),
#   'full_date': '21 janvier 1990',
#   'match': 'KoweÃ¯t - France',
#   'score': '0-1',
#   'type': 'Tournoi du KoweÃ¯t 1990 (amical)',
#   'adversaire': 'KoweÃ¯t',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1990, 1, 21, 0, 0),
#   'year': 1990.0,
#   'outcome': 'win',
#   'no': 1},
#  {'_id': ObjectId('602f75651f9c21001fe15449'),
#   'full_date': '18 novembre 1989',
#   'match': 'France - Chypre',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Chypre',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1989, 11, 18, 0, 0),
#   'year': 1989.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15448'),
#   'full_date': '11 octobre 1989',
#   'match': 'France - Ã\x89cosse',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1989, 10, 11, 0, 0),
#   'year': 1989.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15447'),
#   'full_date': '5 septembre 1989',
#   'match': 'NorvÃ¨ge - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1989, 9, 5, 0, 0),
#   'year': 1989.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15445'),
#   'full_date': '29 avril 1989',
#   'match': 'France - Yougoslavie',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Yougoslavie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1989, 4, 29, 0, 0),
#   'year': 1989.0,
#   'outcome': 'draw',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15444'),
#   'full_date': '8 mars 1989',
#   'match': 'Ã\x89cosse - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1989, 3, 8, 0, 0),
#   'year': 1989.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe15442'),
#   'full_date': '19 novembre 1988',
#   'match': 'Yougoslavie - France',
#   'score': '3-2',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Yougoslavie',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1988, 11, 19, 0, 0),
#   'year': 1988.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe15441'),
#   'full_date': '22 octobre 1988',
#   'match': 'Chypre - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'Chypre',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1988, 10, 22, 0, 0),
#   'year': 1988.0,
#   'outcome': 'draw',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe15440'),
#   'full_date': '28 septembre 1988',
#   'match': 'France - NorvÃ¨ge',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1990',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1988, 9, 28, 0, 0),
#   'year': 1988.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe1542f'),
#   'full_date': '28 juin 1986',
#   'match': 'France - Belgique',
#   'score': '4-2',
#   'type': 'Coupe du monde 1986 (Petite finale)',
#   'adversaire': 'Belgique',
#   'score_france': 4,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1986, 6, 28, 0, 0),
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe1542e'),
#   'full_date': '25 juin 1986',
#   'match': 'France - RFA',
#   'score': '0-2',
#   'type': 'Coupe du monde 1986 (Demi-finale)',
#   'adversaire': 'RFA',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1986, 6, 25, 0, 0),
#   'year': 1986.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe1542b'),
#   'full_date': '9 juin 1986',
#   'match': 'France - Hongrie',
#   'score': '3-0',
#   'type': 'Coupe du monde 1986 (Groupe C)',
#   'adversaire': 'Hongrie',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1986, 6, 9, 0, 0),
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe1542a'),
#   'full_date': '5 juin 1986',
#   'match': 'France - URSS',
#   'score': '1-1',
#   'type': 'Coupe du monde 1986 (Groupe C)',
#   'adversaire': 'URSS',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1986, 6, 5, 0, 0),
#   'year': 1986.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15429'),
#   'full_date': '1er juin 1986',
#   'match': 'France - Canada',
#   'score': '1-0',
#   'type': 'Coupe du monde 1986 (Groupe C)',
#   'adversaire': 'Canada',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1986, 6, 1, 0, 0),
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe1542d'),
#   'full_date': '21 juin 1986',
#   'match': 'BrÃ©sil - France',
#   'score': '1-1 ap(3-4) tab',
#   'type': 'Coupe du monde 1986 (Quart de finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 3.0,
#   'date': datetime.datetime(1986, 6, 21, 0, 0),
#   'year': 1986.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe1542c'),
#   'full_date': '17 juin 1986',
#   'match': 'France - Italie',
#   'score': '2-0',
#   'type': 'Coupe du monde 1986 (HuitiÃ¨me de finale)',
#   'adversaire': 'Italie',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1986, 6, 17, 0, 0),
#   'year': 1986.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15423'),
#   'full_date': '21 aoÃ»t 1985',
#   'match': 'France - Uruguay',
#   'score': '2-0',
#   'type': 'Coupe intercontinentale 1985',
#   'adversaire': 'Uruguay',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1985, 8, 21, 0, 0),
#   'year': 1985.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15426'),
#   'full_date': '16 novembre 1985',
#   'match': 'France - Yougoslavie',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Yougoslavie',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1985, 11, 16, 0, 0),
#   'year': 1985.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15425'),
#   'full_date': '30 octobre 1985',
#   'match': 'France - Luxembourg',
#   'score': '6-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Luxembourg',
#   'score_france': 6,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1985, 10, 30, 0, 0),
#   'year': 1985.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15424'),
#   'full_date': '11 septembre 1985',
#   'match': 'RDA - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'RDA',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1985, 9, 11, 0, 0),
#   'year': 1985.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15422'),
#   'full_date': '2 mai 1985',
#   'match': 'Bulgarie - France',
#   'score': '2-0',
#   'type': 'Qualifications pour la Coupe du monde 1986',
#   'adversaire': 'Bulgarie',
#   'score_france': 0,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1985, 5, 2, 0, 0),
# ...
#   'full_date': '15 juillet 1966',
#   'match': 'Uruguay - France',
#   'score': '2-1',
#   'type': 'Coupe du monde 1966 (Groupe A)',
#   'adversaire': 'Uruguay',
#   'score_france': 1,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1966, 7, 15, 0, 0),
#   'year': 1966.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15393'),
#   'full_date': '13 juillet 1966',
#   'match': 'France - Mexique',
#   'score': '1-1',
#   'type': 'Coupe du monde 1966 (Groupe A)',
#   'adversaire': 'Mexique',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1966, 7, 13, 0, 0),
#   'year': 1966.0,
#   'outcome': 'draw',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe1538f'),
#   'full_date': '6 novembre 1965',
#   'match': 'France - Luxembourg',
#   'score': '4-1',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'Luxembourg',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1965, 11, 6, 0, 0),
#   'year': 1965.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe1538e'),
#   'full_date': '9 octobre 1965',
#   'match': 'France - Yougoslavie',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'Yougoslavie',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1965, 10, 9, 0, 0),
#   'year': 1965.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe1538d'),
#   'full_date': '15 septembre 1965',
#   'match': 'NorvÃ¨ge - France',
#   'score': '0-1',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1965, 9, 15, 0, 0),
#   'year': 1965.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe1538b'),
#   'full_date': '18 avril 1965',
#   'match': 'Yougoslavie - France',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'Yougoslavie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1965, 4, 18, 0, 0),
#   'year': 1965.0,
#   'outcome': 'loss',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe15388'),
#   'full_date': '11 novembre 1964',
#   'match': 'France - NorvÃ¨ge',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'NorvÃ¨ge',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1964, 11, 11, 0, 0),
#   'year': 1964.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15387'),
#   'full_date': '4 octobre 1964',
#   'match': 'Luxembourg - France',
#   'score': '0-2',
#   'type': 'Qualifications pour la Coupe du monde 1966',
#   'adversaire': 'Luxembourg',
#   'score_france': 2,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1964, 10, 4, 0, 0),
#   'year': 1964.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15375'),
#   'full_date': '12 novembre 1961',
#   'match': 'Bulgarie - France',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1962',
#   'adversaire': 'Bulgarie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1961, 11, 12, 0, 0),
#   'year': 1961.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15373'),
#   'full_date': '28 septembre 1961',
#   'match': 'France - Finlande',
#   'score': '5-1',
#   'type': 'Qualifications pour la Coupe du monde 1962',
#   'adversaire': 'Finlande',
#   'score_france': 5,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1961, 9, 28, 0, 0),
#   'year': 1961.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe15377'),
#   'full_date': '16 dÃ©cembre 1961',
#   'match': 'Bulgarie - France',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1962 (Barrage)',
#   'adversaire': 'Bulgarie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1961, 12, 16, 0, 0),
#   'year': 1961.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15370'),
#   'full_date': '11 dÃ©cembre 1960',
#   'match': 'France - Bulgarie',
#   'score': '3-0',
#   'type': 'Qualifications pour la Coupe du monde 1962',
#   'adversaire': 'Bulgarie',
#   'score_france': 3,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1960, 12, 11, 0, 0),
#   'year': 1960.0,
#   'outcome': 'win',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe1536c'),
#   'full_date': '25 septembre 1960',
#   'match': 'Finlande - France',
#   'score': '1-2',
#   'type': 'Qualifications pour la Coupe du monde 1962',
#   'adversaire': 'Finlande',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1960, 9, 25, 0, 0),
#   'year': 1960.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe1535c'),
#   'full_date': '28 juin 1958',
#   'match': 'France - RFA',
#   'score': '6-3',
#   'type': 'Coupe du monde 1958 (Petite finale)',
#   'adversaire': 'RFA',
#   'score_france': 6,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1958, 6, 28, 0, 0),
#   'year': 1958.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe1535b'),
#   'full_date': '24 juin 1958',
#   'match': 'BrÃ©sil - France',
#   'score': '5-2',
#   'type': 'Coupe du monde 1958 (Demi-finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 2,
#   'score_adversaire': 5,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1958, 6, 24, 0, 0),
#   'year': 1958.0,
#   'outcome': 'loss',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15359'),
#   'full_date': '15 juin 1958',
#   'match': 'France - Ã\x89cosse',
#   'score': '2-1',
#   'type': 'Coupe du monde 1958 (Groupe B)',
#   'adversaire': 'Ã\x89cosse',
#   'score_france': 2,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1958, 6, 15, 0, 0),
#   'year': 1958.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15358'),
#   'full_date': '11 juin 1958',
#   'match': 'Yougoslavie - France',
#   'score': '3-2',
#   'type': 'Coupe du monde 1958 (Groupe B)',
#   'adversaire': 'Yougoslavie',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1958, 6, 11, 0, 0),
#   'year': 1958.0,
#   'outcome': 'loss',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15357'),
#   'full_date': '8 juin 1958',
#   'match': 'France - Paraguay',
#   'score': '7-3',
#   'type': 'Coupe du monde 1958 (Groupe B)',
#   'adversaire': 'Paraguay',
#   'score_france': 7,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1958, 6, 8, 0, 0),
#   'year': 1958.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe1535a'),
#   'full_date': '19 juin 1958',
#   'match': 'France - Irlande du Nord',
#   'score': '4-0',
#   'type': 'Coupe du monde 1958 (Quart de finale)',
#   'adversaire': 'Irlande du Nord',
#   'score_france': 4,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1958, 6, 19, 0, 0),
#   'year': 1958.0,
#   'outcome': 'win',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15352'),
#   'full_date': '27 octobre 1957',
#   'match': 'Belgique - France',
#   'score': '0-0',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1957, 10, 27, 0, 0),
#   'year': 1957.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe15350'),
#   'full_date': '1er septembre 1957',
#   'match': 'Islande - France',
#   'score': '1-5',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Islande',
#   'score_france': 5,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1957, 9, 1, 0, 0),
#   'year': 1957.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe1534f'),
#   'full_date': '2 juin 1957',
#   'match': 'France - Islande',
#   'score': '8-0',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Islande',
#   'score_france': 8,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1957, 6, 2, 0, 0),
#   'year': 1957.0,
#   'outcome': 'win',
#   'no': 2},
#  {'_id': ObjectId('602f75651f9c21001fe1534d'),
#   'full_date': '11 novembre 1956',
#   'match': 'France - Belgique',
#   'score': '6-3',
#   'type': 'Qualifications pour la Coupe du monde 1958',
#   'adversaire': 'Belgique',
#   'score_france': 6,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1956, 11, 11, 0, 0),
#   'year': 1956.0,
#   'outcome': 'win',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe1533f'),
#   'full_date': '19 juin 1954',
#   'match': 'France - Mexique',
#   'score': '3-2',
#   'type': 'Coupe du monde 1954 (Groupe A)',
#   'adversaire': 'Mexique',
#   'score_france': 3,
#   'score_adversaire': 2,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1954, 6, 19, 0, 0),
#   'year': 1954.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe1533e'),
#   'full_date': '16 juin 1954',
#   'match': 'Yougoslavie - France',
#   'score': '1-0',
#   'type': 'Coupe du monde 1954 (Groupe A)',
#   'adversaire': 'Yougoslavie',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1954, 6, 16, 0, 0),
#   'year': 1954.0,
#   'outcome': 'loss',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe1533b'),
#   'full_date': '17 dÃ©cembre 1953',
#   'match': 'France - Luxembourg',
#   'score': '8-0',
#   'type': 'Qualifications pour la Coupe du monde 1954',
#   'adversaire': 'Luxembourg',
#   'score_france': 8,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1953, 12, 17, 0, 0),
#   'year': 1953.0,
#   'outcome': 'win',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe1533a'),
#   'full_date': '25 novembre 1953',
#   'match': 'France - Irlande',
#   'score': '1-0',
#   'type': 'Qualifications pour la Coupe du monde 1954',
#   'adversaire': 'Irlande',
#   'score_france': 1,
#   'score_adversaire': 0,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1953, 11, 25, 0, 0),
#   'year': 1953.0,
#   'outcome': 'win',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15337'),
#   'full_date': '4 octobre 1953',
#   'match': 'Irlande - France',
#   'score': '3-5',
#   'type': 'Qualifications pour la Coupe du monde 1954',
#   'adversaire': 'Irlande',
#   'score_france': 5,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1953, 10, 4, 0, 0),
#   'year': 1953.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe15336'),
#   'full_date': '20 septembre 1953',
#   'match': 'Luxembourg - France',
#   'score': '1-6',
#   'type': 'Qualifications pour la Coupe du monde 1954',
#   'adversaire': 'Luxembourg',
#   'score_france': 6,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1953, 9, 20, 0, 0),
#   'year': 1953.0,
#   'outcome': 'win',
#   'no': 3},
#  {'_id': ObjectId('602f75651f9c21001fe1531e'),
#   'full_date': '30 octobre 1949',
#   'match': 'France - Yougoslavie',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1950',
#   'adversaire': 'Yougoslavie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1949, 10, 30, 0, 0),
#   'year': 1949.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe1531d'),
#   'full_date': '9 octobre 1949',
#   'match': 'Yougoslavie - France',
#   'score': '1-1',
#   'type': 'Qualifications pour la Coupe du monde 1950',
#   'adversaire': 'Yougoslavie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1949, 10, 9, 0, 0),
#   'year': 1949.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe15320'),
#   'full_date': '11 dÃ©cembre 1949',
#   'match': 'Yougoslavie - France',
#   'score': '3-2',
#   'type': 'Qualifications pour la\nCoupe du monde 1950 (Barrage)',
#   'adversaire': 'Yougoslavie',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1949, 12, 11, 0, 0),
#   'year': 1949.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe152fb'),
#   'full_date': '12 juin 1938',
#   'match': 'France - Italie',
#   'score': '1-3',
#   'type': 'Coupe du monde 1938 (Quart de finale)',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1938, 6, 12, 0, 0),
#   'year': 1938.0,
#   'outcome': 'loss',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe152fa'),
#   'full_date': '5 juin 1938',
#   'match': 'France - Belgique',
#   'score': '3-1',
#   'type': 'Coupe du monde 1938 (HuitiÃ¨me de finale)',
#   'adversaire': 'Belgique',
#   'score_france': 3,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1938, 6, 5, 0, 0),
#   'year': 1938.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe152e3'),
#   'full_date': '27 mai 1934',
#   'match': 'Autriche - France',
#   'score': '3-2',
#   'type': 'Coupe du monde 1934 (HuitiÃ¨me de finale)',
#   'adversaire': 'Autriche',
#   'score_france': 2,
#   'score_adversaire': 3,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1934, 5, 27, 0, 0),
#   'year': 1934.0,
#   'outcome': 'loss',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe152e1'),
#   'full_date': '15 avril 1934',
#   'match': 'Luxembourg - France',
#   'score': '1-6',
#   'type': 'Qualifications pour la Coupe du monde 1934',
#   'adversaire': 'Luxembourg',
#   'score_france': 6,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1934, 4, 15, 0, 0),
#   'year': 1934.0,
#   'outcome': 'win',
#   'no': 4},
#  {'_id': ObjectId('602f75651f9c21001fe152c9'),
#   'full_date': '19 juillet 1930',
#   'match': 'Chili - France',
#   'score': '1-0',
#   'type': 'Coupe du monde 1930 (Groupe 1)',
#   'adversaire': 'Chili',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1930, 7, 19, 0, 0),
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 9},
#  {'_id': ObjectId('602f75651f9c21001fe152c8'),
#   'full_date': '15 juillet 1930',
#   'match': 'Argentine - France',
#   'score': '1-0',
#   'type': 'Coupe du monde 1930 (Groupe 1)',
#   'adversaire': 'Argentine',
#   'score_france': 0,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1930, 7, 15, 0, 0),
#   'year': 1930.0,
#   'outcome': 'loss',
#   'no': 8},
#  {'_id': ObjectId('602f75651f9c21001fe152c7'),
#   'full_date': '13 juillet 1930',
#   'match': 'France - Mexique',
#   'score': '4-1',
#   'type': 'Coupe du monde 1930 (Groupe 1)[73]',
#   'adversaire': 'Mexique',
#   'score_france': 4,
#   'score_adversaire': 1,
#   'penalty_france': nan,
#   'penalty_adversaire': nan,
#   'date': datetime.datetime(1930, 7, 13, 0, 0),
#   'year': 1930.0,
#   'outcome': 'win',
#   'no': 7}]

# %% [markdown]
# La séance de tirs aux buts doit être l'un des moments où un joueur de foot ressent le plus de pression, dans cette requête vous pouvez voir si oui ou non les bleux ont réussi à la surmonter grâce à cette liste qui nous montre tous les matchs de l'équipe de france qui ont dû allé jusqu'aux tirs au buts.

# %%
query = collection.find({"penalty_france": {"$ne" : np.nan}})
list(query)
# Out:
# [{'_id': ObjectId('602f75651f9c21001fe15409'),
#   'full_date': '8 juillet 1982',
#   'match': 'RFA - France [6]',
#   'score': '3-3 ap(5-4) tab',
#   'type': 'Coupe du monde 1982 (Demi-finale)',
#   'adversaire': 'RFA',
#   'score_france': 3,
#   'score_adversaire': 3,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 5.0,
#   'date': datetime.datetime(1982, 7, 8, 0, 0),
#   'year': 1982.0,
#   'outcome': 'draw',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe1542d'),
#   'full_date': '21 juin 1986',
#   'match': 'BrÃ©sil - France',
#   'score': '1-1 ap(3-4) tab',
#   'type': 'Coupe du monde 1986 (Quart de finale)',
#   'adversaire': 'BrÃ©sil',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 3.0,
#   'date': datetime.datetime(1986, 6, 21, 0, 0),
#   'year': 1986.0,
#   'outcome': 'draw',
#   'no': 7},
#  {'_id': ObjectId('602f75651f9c21001fe15486'),
#   'full_date': '22 juin 1996',
#   'match': 'France - Pays-Bas',
#   'score': '0-0 ap(5-4) tab',
#   'type': 'Euro 1996 (Quart de finale)',
#   'adversaire': 'Pays-Bas',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': 5.0,
#   'penalty_adversaire': 4.0,
#   'date': datetime.datetime(1996, 6, 22, 0, 0),
#   'year': 1996.0,
#   'outcome': 'draw',
#   'no': 10},
#  {'_id': ObjectId('602f75651f9c21001fe15487'),
#   'full_date': '26 juin 1996',
#   'match': 'RÃ©p. tchÃ¨que - France',
#   'score': '0-0 ap(6-5) tab',
#   'type': 'Euro 1996 (Demi-finale)',
#   'adversaire': 'RÃ©p. tchÃ¨que',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': 5.0,
#   'penalty_adversaire': 6.0,
#   'date': datetime.datetime(1996, 6, 26, 0, 0),
#   'year': 1996.0,
#   'outcome': 'draw',
#   'no': 11},
#  {'_id': ObjectId('602f75651f9c21001fe15498'),
#   'full_date': '29 mai 1998',
#   'match': 'Maroc - France',
#   'score': '2-2(6-5) tab',
#   'type': 'Tournoi Hassan II 1998 (amical)',
#   'adversaire': 'Maroc',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': 5.0,
#   'penalty_adversaire': 6.0,
#   'date': datetime.datetime(1998, 5, 29, 0, 0),
#   'year': 1998.0,
#   'outcome': 'draw',
#   'no': 6},
#  {'_id': ObjectId('602f75651f9c21001fe1549e'),
#   'full_date': '3 juillet 1998',
#   'match': 'France â\x80\x93 Italie',
#   'score': '0-0 ap(4-3) tab',
#   'type': 'Coupe du monde 1998 (Quart de finale)',
#   'adversaire': 'France â\x80\x93 Italie',
#   'score_france': 0,
#   'score_adversaire': 0,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 3.0,
#   'date': datetime.datetime(1998, 7, 3, 0, 0),
#   'year': 1998.0,
#   'outcome': 'draw',
#   'no': 12},
#  {'_id': ObjectId('602f75651f9c21001fe154b4'),
#   'full_date': '4 juin 2000',
#   'match': 'France - Japon',
#   'score': '2-2(4-2) tab',
#   'type': 'Tournoi Hassan II 2000 (amical)',
#   'adversaire': 'Japon',
#   'score_france': 2,
#   'score_adversaire': 2,
#   'penalty_france': 4.0,
#   'penalty_adversaire': 2.0,
#   'date': datetime.datetime(2000, 6, 4, 0, 0),
#   'year': 2000.0,
#   'outcome': 'draw',
#   'no': 5},
#  {'_id': ObjectId('602f75651f9c21001fe1550d'),
#   'full_date': '9 juillet 2006',
#   'match': 'Italie - France',
#   'score': '1-1 ap(5-3) tab',
#   'type': 'Coupe du monde 2006 (Finale)',
#   'adversaire': 'Italie',
#   'score_france': 1,
#   'score_adversaire': 1,
#   'penalty_france': 3.0,
#   'penalty_adversaire': 5.0,
#   'date': datetime.datetime(2006, 7, 9, 0, 0),
#   'year': 2006.0,
#   'outcome': 'draw',
#   'no': 11}]
